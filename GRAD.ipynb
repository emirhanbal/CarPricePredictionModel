# %% [markdown]
# # CAR PRICE PREDICTION MODEL #MAIN

# %% [markdown]
# Kütüphane ve modül eklemelerinin yaptım. Seleniumu projeme dahil ettim ve ilan sitesine yönlendirdim.
# İlk olarak anasayfada görünen ilanların linklerini aldım ki daha sonrasında bu ilanların içeriğine ulaşabileyim.

# %%
from selenium import webdriver
from time import sleep
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

##KUTUPHANELERI IMPORT ETTIK VE KOMUT ISTEMINDEN MODULLERI YUKLEDIK

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
driver.set_window_size(1250,740)
driver.set_window_position(0,0)

##CHROME DRIVERIMIZI YUKLEDIK

#LINKIMIZI BELIRLEDIK HER SAYFA PAGE2-3 DİYE GİTTİĞİ İÇİN PAGE NUMBERS BELIRLEDIK
mainLink = "https://www.arabam.com/ikinci-el"
page_numbers = range(2, 4)
#Şimdilik 2 sayfa üzerinde çalışmak için 2,4 belirledim

#BOS BIR LISTE OLUSTURDUM DATALARI BURADA TUTMAK ICIN
linklist = []

#HER SAYFADA TEK TEK DEVAM EDEBILSIN DIYE PAGE NUMBERS BELIRLEDIM BUNA GÖRE URL DUZENLEYIP O URLYE GIDECEK
#ZATEN URL BELLİ BİR DÜZENDE DEVAM EDİYOR.
for number in page_numbers:
    url = mainLink + '?page=' + str(number)
    driver.get(url)
    sleep(2)
#FONKSIYON OLARAK TAGNAME A OLAN BLOĞUN İÇİNDEKİ LİNKLERİ ALACAK BIR FOR DONGUSU DUZENLEDIM
    def get_links(driver, xpath):
        a = driver.find_element(By.XPATH, '//*[@id="js-hook-missing-space-content"]/div[2]/div[2]')
        lnks = a.find_elements(By.TAG_NAME, "a")
        for lnk in lnks:
            href = lnk.get_attribute("href")
            if href and href not in linklist:
                linklist.append(href)
        return linklist
    #HER LINKTEN 7 ADET OLDUĞU ICIN LISTENIN ICINDE VAR MI VARSA ALMA YOKSA AL GIBI BIR IF ELSE DUZENLEDIM (HER LINKTEN BIR TANE OLMASI ICIN)
    linklist = get_links(driver, '//*[@id="js-hook-missing-space-content"]/div[2]/div[2]')
    
print(linklist)
len(linklist)
# Out:
# [WDM] - Downloading: 100%|████████████████████████████████████████████████████████| 6.80M/6.80M [00:02<00:00, 2.98MB/s]
# ['https://www.arabam.com/ilan/galeriden-satilik-mercedes-benz-c-180-amg/mtm-otomotiv-den-ilk-sahibinden-95-000-km-de-hatasiz-boyasiz-imzali-seri/22216901', 'https://www.arabam.com/ilan/galeriden-satilik-fiat-fiorino-combi-1-4-fire-premio/galeriden-fiat-fiorino-combi-1-4-fire-premio-2022-model-kirklareli/22016561', 'https://www.arabam.com/ilan/galeriden-satilik-nissan-qashqai-1-5-dci-tekna-sky-pack/2014-model-qashqai-1-5-dci-sky-pack-hatasiz/22587478', 'https://www.arabam.com/ilan/galeriden-satilik-ford-transit-courier-1-5-tdci-trend/0-arac-sorunsuz-ford-courier-transit/22587475', 'https://www.arabam.com/ilan/galeriden-satilik-renault-clio-0-9-tce-sport-tourer-joy/hatasiz-boyasiz-degisensiz-ekstrali-clio-40-bin-km/22587414',
'https://www.arabam.com/ilan/galeriden-satilik-volkswagen-passat-1-4-tsi-bluemotion-highline/2014-passat-1-4-tsi-bmt-highline-160hp-sunroof-hatasiz-145-000km/21930033', 'https://www.arabam.com/ilan/galeriden-satilik-renault-master-2-3-dci/galeriden-renault-master-2-3-dci-konya/22447352', 'https://www.arabam.com/ilan/galeriden-satilik-ford-tourneo-courier-1-5-tdci-titanium-plus/babacan-otomotivden-2023-hatasiz-boyasiz-tramersiz-sifir-courier/22586475', 'https://www.arabam.com/ilan/galeriden-satilik-bmw-1-serisi-118i-sport-line/aydincan-auto-bmw-1-18i-sport-line-hayalet-gosterge-geri-grs/22586476', 'https://www.arabam.com/ilan/galeriden-satilik-mercedes-benz-c-180-kompressor-blueefficiency-amg/asker-otomotivden-2010-model-mercedes-benz-kompresor-amg/22586432', 'https ...
# 41

# %% [markdown]
# Burada anasayfadaki ilanların linklerini listemde tutuyorum. Şimdi Selenium'u bu listedeki linklere yönlendireceğim

# %%
# LINK LISTEMDEKI LINKLERE GIDECEK BIR YAPI INSAA ETMEK ISTIYORUM BU YUZDEN ONCE LINKLERI LISTEMDE KONTROL ETTIM
cardetail = []
for link in linklist:
    # GET METHODUYLA LISTEDEKI LINKLERE SELENIUMU GONDERDIM
    driver.get(link)
    
    #LINKLERIN TITTLELARINI YAZDIRDIM
    #print(driver.title)
    
    
    
    #HTML YAPISI ICINDE LI SPAN OLARAK BULUNAN !BENIM ASIL IHTIYACIM OLAN! DATALARI CEKECEK BIR FOR DONGUSU OLUSTURDUM
    for li in driver.find_elements(By.XPATH, '//*[@id="js-hook-for-observer-detail"]/div[2]'):
        #print(li.text)
        item = li.text
        cardetail.append(item)
        
# Close browser
#element = driver.find_element_by_xpath('//*[@id="js-hook-for-observer-detail"]/div[2]')
 #   print(element.text)

# %%
cardetail
# Out:
# ['1.620.000 TL\nTaşıt Kredini Hesapla\nANKARA / GÖLBAŞI / KIZILCAŞAR MAHALLESİ\nİlan No:\n22216901\nİlan Tarihi:\n09 Mayıs 2023\nMarka:\nMercedes - Benz\nSeri:\nC\nModel:\nC 180 AMG\nYıl:\n2015\nKilometre:\n95.000 km\nVites Tipi:\nOtomatik\nYakıt Tipi:\nBenzin\nKasa Tipi:\nSedan\nMotor Hacmi:\n1595 cc\nMotor Gücü:\n156 hp\nÇekiş:\nArkadan İtiş\nOrt. Yakıt Tüketimi:\n5,8 lt\nYakıt Deposu:\n41 lt\nBoya-değişen:\n1 değişen\nTakasa Uygun:\nTakasa Uygun\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '542.000 TL\nTaşıt Kredini Hesapla\nKIRKLARELİ / LÜLEBURGAZ / YENİ MAHALLESİ\nİlan No:\n22016561\nİlan Tarihi:\n09 Mayıs 2023\nMarka:\nFiat\nSeri:\nFiorino\nModel:\nFiorino Combi 1.4 Fire Premio\nYıl:\n2022\nKilometre:\n8.700 km\nVites Tipi:\nDüz\nYakıt Tipi:\nBenzin\nKasa Tipi:\nCamlı Van\nMotor Hacmi:\n1368 cm3\nMotor Gücü:\n77 hp\nÇekiş:\n4x4\nKoltuk Sayısı:\n3+1\nAraç Cinsi (Ruhsat):\nKamyonet\nBoya-değişen:\nTamamı orjinal\nTakasa Uygun:\nTakasa Uygun\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '795.000 TL\nTaşıt Kredini Hesapla\nANKARA / ÇANKAYA / EMEK MAHALLESİ\nİlan No:\n22587478\nİlan Tarihi:\n09 Mayıs 2023\nMarka:\nNissan\nSeri:\nQashqai\nModel:\n1.5 dCi Tekna Sky Pack\nYıl:\n2014\nKilometre:\n148.000 km\nVites Tipi:\nDüz\nYakıt Tipi:\nDizel\nKasa Tipi:\nSUV\nMotor Hacmi:\n1401 - 1600 cm3\nMotor Gücü:\n101 - 125 HP\nÇekiş:\nÖnden Çekiş\nBoya-değişen:\n1 boyalı\nTakasa Uygun:\nTakasa Uygun\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  
nBoya-değişen:\nBelirtilmemiş\nTakasa Uygun:\nTakasa Uygun\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '618.000 TL\nTaşıt Kredini Hesapla\nİSTANBUL / BAĞCILAR / 100. YIL MAHALLESİ\nİlan No:\n22586961\nİlan Tarihi:\n09 Mayıs 2023\nMarka:\nVolkswagen\nSeri:\nJetta\nModel:\n1.2 TSi Trendline\nYıl:\n2014\nKilometre:\n161.800 km\nVites Tipi:\nYarı Otomatik\nYakıt Tipi:\nBenzin\nKasa Tipi:\nSedan\nMotor Hacmi:\n1197 cc\nMotor Gücü:\n105 hp\nÇekiş:\nÖnden Çekiş\nOrt. Yakıt Tüketimi:\n5,4 lt\nYakıt Deposu:\n55 lt\nBoya-değişen:\n1 değişen, 3 boyalı\nTakasa Uygun:\nTakasa Uygun\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '348.500 TL\nTaşıt Kredini Hesapla\nİZMİR / BALÇOVA / ÇETİN EMEÇ MAHALLESİ\nİlan No:\n22586919\nİlan Tarihi:\n09 Mayıs 2023\nMarka:\nRenault\nSeri:\nSymbol\nModel:\n1.5 dCi Authentique\nYıl:\n2011\nKilometre:\n154.000 km\nVites Tipi:\nDüz\nYakıt Tipi:\nDizel\nKasa Tipi:\nSedan\nMotor Hacmi:\n1461 cc\nMotor Gücü:\n65 hp\nÇekiş:\nÖnden Çekiş\nOrt. Yakıt Tüketimi:\n4,5 lt\nYakıt Deposu:\n50 lt\nBoya-değişen:\nBelirtilmemiş\nTakasa Uygun:\nTakasa Uygun Değil\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '430.000 TL\nTaşıt Kredini Hesapla\nİSTANBUL / TUZLA / ŞİFA MAHALLESİ\nİlan No:\n22586812\nİlan Tarihi:\n09 Mayıs 2023\nMarka:\nRenault\nSeri:\nClio\nModel:\n1.5 dCi Joy\nYıl:\n2014\nKilometre:\n205.000 km\nVites Tipi:\nDüz\nYakıt Tipi:\nDizel\nKasa Tipi:\nHatchback/5\nMotor Hacmi:\n1461 cc\nMotor Gücü:\n75 hp\nÇekiş:\nÖnden Çekiş\nOrt. Yakıt Tüketimi:\n3,6 lt\nYakıt Deposu:\n45 lt\nBoya-değişen:\n5 boyalı\nTakasa Uygun:\nTakasa Uygun\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '345.000 TL\nTaşıt Kredini Hesapla\nİZMİR / GAZİEMİR / BEYAZEVLER MAHALLESİ\nİlan No:\n22457603\nİlan Tarihi:\n09 Mayıs 2023\nMarka:\nRenault\nSeri:\nSymbol\nModel:\n1.5 dCi Expression\nYıl:\n2009\nKilometre:\n213.000 km\nVites Tipi:\nDüz\nYakıt Tipi:\nDizel\nKasa Tipi:\nSedan\nMotor Hacmi:\n1461 cc\nMotor Gücü:\n85 hp\nÇekiş:\nÖnden Çekiş\nOrt. Yakıt Tüketimi:\n4,3 lt\nYakıt Deposu:\n50 lt\nBoya-değişen:\nBelirtilmemiş\nTakasa Uygun:\nTakasa Uygun\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '675.000 TL\nTaşıt Kredini Hesapla\nANKARA / YENİMAHALLE / PAMUKLAR MAHALLESİ\nİlan No:\n22586715\nİlan Tarihi:\n09 Mayıs 2023\nMarka:\nPeugeot\nSeri:\n308\nModel:\n1.6 BlueHdi Active\nYıl:\n2017\nKilometre:\n170.000 km\nVites Tipi:\nOtomatik\nYakıt Tipi:\nDizel\nKasa Tipi:\nHatchback/5\nMotor Hacmi:\n1560 cc\nMotor Gücü:\n122 hp\nÇekiş:\nÖnden Çekiş\nOrt. Yakıt Tüketimi:\n3,7 lt\nYakıt Deposu:\n53 lt\nBoya-değişen:\n2 boyalı\nTakasa Uygun:\nTakasa Uygun Değil\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '238.750 TL\nTaşıt Kredini Hesapla\nBURSA / İNEGÖL / ŞEHİTLER MAHALLESİ\nİlan No:\n22586730\nİlan Tarihi:\n09 Mayıs 2023\nMarka:\nFiat\nSeri:\nAlbea\nModel:\n1.2 Active\nYıl:\n2004\nKilometre:\n190.099 km\nVites Tipi:\nDüz\nYakıt Tipi:\nBenzin\nKasa Tipi:\nSedan\nMotor Hacmi:\n1242 cc\nMotor Gücü:\n80 hp\nÇekiş:\nÖnden Çekiş\nOrt. Yakıt Tüketimi:\n7 lt\nYakıt Deposu:\n47 lt\nBoya-değişen:\nTamamı boyalı\nTakasa Uygun:\n-\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '899.900 TL\nTaşıt Kredini Hesapla\nDENİZLİ / SARAYKÖY / BEYLERBEYİ MAHALLESİ\nİlan No:\n21930033\nİlan Tarihi:\n09 Mayıs 2023\nMarka:\nVolkswagen\nSeri:\nPassat\nModel:\n1.4 TSi BlueMotion Highline\nYıl:\n2014\nKilometre:\n145.000 km\nVites Tipi:\nYarı Otomatik\nYakıt Tipi:\nBenzin\nKasa Tipi:\nSedan\nMotor Hacmi:\n1390 cc\nMotor Gücü:\n160 hp\nÇekiş:\nÖnden Çekiş\nOrt. Yakıt Tüketimi:\n6,7 lt\nYakıt Deposu:\n70 lt\nBoya-değişen:\nBelirtilmemiş\nTakasa Uygun:\nTakasa Uygun Değil\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  
atik\nYakıt Tipi:\nDizel\nKasa Tipi:\nSedan\nMotor Hacmi:\n1598 cc\nMotor Gücü:\n120 hp\nÇekiş:\nÖnden Çekiş\nOrt. Yakıt Tüketimi:\n4 lt\nYakıt Deposu:\n59 lt\nBoya-değişen:\n1 değişen, 9 boyalı\nTakasa Uygun:\nTakasa Uygun Değil\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '323.000 TL\nTaşıt Kredini Hesapla\nORDU / FATSA / MUSTAFAKEMALPAŞA MAHALLESİ\nİlan No:\n22549990\nİlan Tarihi:\n09 Mayıs 2023\nMarka:\nRenault\nSeri:\nMegane\nModel:\n1.5 dCi Dynamique\nYıl:\n2005\nKilometre:\n235.750 km\nVites Tipi:\nDüz\nYakıt Tipi:\nDizel\nKasa Tipi:\nSedan\nMotor Hacmi:\n1461 cc\nMotor Gücü:\n80 hp\nÇekiş:\nÖnden Çekiş\nOrt. Yakıt Tüketimi:\n4,6 lt\nYakıt Deposu:\n60 lt\nBoya-değişen:\n5 boyalı\nTakasa Uygun:\nTakasa Uygun Değil\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '515.000 TL\nTaşıt Kredini Hesapla\nBURSA / GEMLİK / EŞREF DİNÇER MAHALLESİ\nİlan No:\n22586124\nİlan Tarihi:\n09 Mayıs 2023\nMarka:\nVolkswagen\nSeri:\nCaddy\nModel:\n1.6 TDI Trendline\nYıl:\n2011\nKilometre:\n227.000 km\nVites Tipi:\nYarı Otomatik\nYakıt Tipi:\nDizel\nKasa Tipi:\nCamlı Van\nMotor Hacmi:\n1598 cm3\nMotor Gücü:\n102 hp\nÇekiş:\n4x2 (Arkadan İtişli)\nKoltuk Sayısı:\n4+1\nAraç Cinsi (Ruhsat):\nKamyonet\nBoya-değişen:\n5 boyalı\nTakasa Uygun:\nTakasa Uygun\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '485.000 TL\nTaşıt Kredini Hesapla\nŞANLIURFA / SURUÇ / SARAYALTI MAHALLESİ\nİlan No:\n22117111\nİlan Tarihi:\n09 Mayıs 2023\nMarka:\nMercedes - Benz\nSeri:\nSprinter\nModel:\n315 CDI\nYıl:\n2009\nKilometre:\n730.000 km\nVites Tipi:\nDüz\nYakıt Tipi:\nDizel\nMotor Hacmi:\n2148 cm3\nMotor Gücü:\n150 hp\nRenk:\nBeyaz\nKoltuk Sayısı:\n16+1\nTavan Tipi:\nNormal Tavan\nAracın ilk sahibiyim:\nİlk Sahibi Değilim\nYakıt Deposu:\n75 lt\nTakasa Uygun:\nTakasa Uygun\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '985.000 TL\nTaşıt Kredini Hesapla\nBALIKESİR / EDREMİT / CENNETAYAĞI MAHALLESİ\nİlan No:\n22118110\nİlan Tarihi:\n09 Mayıs 2023\nMarka:\nVolkswagen\nSeri:\nPassat\nModel:\n1.6 TDi BlueMotion Comfortline\nYıl:\n2016\nKilometre:\n168.000 km\nVites Tipi:\nYarı Otomatik\nYakıt Tipi:\nDizel\nKasa Tipi:\nSedan\nMotor Hacmi:\n1598 cc\nMotor Gücü:\n120 hp\nÇekiş:\nÖnden Çekiş\nOrt. Yakıt Tüketimi:\n4 lt\nYakıt Deposu:\n66 lt\nBoya-değişen:\nBelirtilmemiş\nTakasa Uygun:\nTakasa Uygun\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '1.475.000 TL\nTaşıt Kredini Hesapla\nUŞAK / MERKEZ / DURAK MAHALLESİ\nİlan No:\n22586003\nİlan Tarihi:\n09 Mayıs 2023\nMarka:\nMercedes - Benz\nSeri:\nE\nModel:\n180 AMG\nYıl:\n2013\nKilometre:\n153.000 km\nVites Tipi:\nOtomatik\nYakıt Tipi:\nBenzin\nKasa Tipi:\nSedan\nMotor Hacmi:\n1595 cc\nMotor Gücü:\n156 hp\nÇekiş:\nArkadan İtiş\nOrt. Yakıt Tüketimi:\n6,6 lt\nYakıt Deposu:\n59 lt\nBoya-değişen:\nTamamı orjinal\nTakasa Uygun:\nTakasa Uygun\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '1.045.000 TL\nTaşıt Kredini Hesapla\nİSTANBUL / BAĞCILAR / MAHMUTBEY MAHALLESİ\nİlan No:\n22446906\nİlan Tarihi:\n09 Mayıs 2023\nMarka:\nPeugeot\nSeri:\n2008\nModel:\n1.5 BlueHDI Active\nYıl:\n2020\nKilometre:\n36.000 km\nVites Tipi:\nOtomatik\nYakıt Tipi:\nDizel\nKasa Tipi:\nCrossover\nMotor Hacmi:\n1499 cc\nMotor Gücü:\n132 hp\nÇekiş:\nÖnden Çekiş\nOrt. Yakıt Tüketimi:\n3,8 lt\nYakıt Deposu:\n41 lt\nBoya-değişen:\nBelirtilmemiş\nTakasa Uygun:\nTakasa Uygun\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '1.148.000 TL\nTaşıt Kredini Hesapla\nKİLİS / MERKEZ / İZZETTİN İYİGÜN PAŞA MAHALLESİ\nİlan No:\n22585911\nİlan Tarihi:\n09 Mayıs 2023\nMarka:\nPeugeot\nSeri:\n3008\nModel:\n1.5 BlueHDI Allure Selection\nYıl:\n2019\nKilometre:\n82.000 km\nVites Tipi:\nOtomatik\nYakıt Tipi:\nDizel\nKasa Tipi:\nCrossover\nMotor Hacmi:\n1499 cc\nMotor Gücü:\n132 hp\nÇekiş:\nÖnden Çekiş\nOrt. Yakıt Tüketimi:\n4,1 lt\nYakıt Deposu:\n53 lt\nBoya-değişen:\nBelirtilmemiş\nTakasa Uygun:\nTakasa Uygun\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '529.000 TL\nTaşıt Kredini Hesapla\nANKARA / ÇANKAYA / BİRLİK MAHALLESİ\nİlan No:\n22364438\nİlan Tarihi:\n09 Mayıs 2023\nMarka:\nVolvo\nSeri:\nS40\nModel:\n1.6 D\nYıl:\n2011\nKilometre:\n218.000 km\nVites Tipi:\nDüz\nYakıt Tipi:\nDizel\nKasa Tipi:\nSedan\nMotor Hacmi:\n1560 cc\nMotor Gücü:\n115 hp\nÇekiş:\nÖnden Çekiş\nOrt. Yakıt Tüketimi:\n4,3 lt\nYakıt Deposu:\n55 lt\nBoya-değişen:\nTamamı orjinal\nTakasa Uygun:\nTakasa Uygun\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '745.000 TL\nTaşıt Kredini Hesapla\nBURSA / GEMLİK / EŞREF DİNÇER MAHALLESİ\nİlan No:\n22585780\nİlan Tarihi:\n09 Mayıs 2023\nMarka:\nFiat\nSeri:\nEgea\nModel:\n1.3 Multijet Easy Plus\nYıl:\n2022\nKilometre:\n6.100 km\nVites Tipi:\nDüz\nYakıt Tipi:\nDizel\nKasa Tipi:\nSedan\nMotor Hacmi:\n1248 cc\nMotor Gücü:\n95 hp\nÇekiş:\nÖnden Çekiş\nOrt. Yakıt Tüketimi:\n4,1 lt\nYakıt Deposu:\n50 lt\nBoya-değişen:\nTamamı orjinal\nTakasa Uygun:\nTakasa Uygun\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '749.900 TL\nTaşıt Kredini Hesapla\nİSTANBUL / ATAŞEHİR / KÜÇÜKBAKKALKÖY MAHALLESİ\nİlan No:\n21706544\nİlan Tarihi:\n09 Mayıs 2023\nMarka:\nMercedes - Benz\nSeri:\nC\nModel:\nC 180 Kompressor BlueEfficiency Luxury\nYıl:\n2010\nKilometre:\n192.000 km\nVites Tipi:\nOtomatik\nYakıt Tipi:\nLPG & Benzin\nKasa Tipi:\nSedan\nMotor Hacmi:\n1597 cc\nMotor Gücü:\n156 hp\nÇekiş:\nArkadan İtiş\nOrt. Yakıt Tüketimi:\n6,5 lt\nYakıt Deposu:\n66 lt\nBoya-değişen:\nBelirtilmemiş\nTakasa Uygun:\nTakasa Uygun Değil\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş']

# %% [markdown]
# Selenium linklere gitti ve her linkin tablosundaki verileri ayrı ayrı topladı.

# %%
cardetail[0]
# Out:
# '1.620.000 TL\nTaşıt Kredini Hesapla\nANKARA / GÖLBAŞI / KIZILCAŞAR MAHALLESİ\nİlan No:\n22216901\nİlan Tarihi:\n09 Mayıs 2023\nMarka:\nMercedes - Benz\nSeri:\nC\nModel:\nC 180 AMG\nYıl:\n2015\nKilometre:\n95.000 km\nVites Tipi:\nOtomatik\nYakıt Tipi:\nBenzin\nKasa Tipi:\nSedan\nMotor Hacmi:\n1595 cc\nMotor Gücü:\n156 hp\nÇekiş:\nArkadan İtiş\nOrt. Yakıt Tüketimi:\n5,8 lt\nYakıt Deposu:\n41 lt\nBoya-değişen:\n1 değişen\nTakasa Uygun:\nTakasa Uygun\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş'

# %%
type(cardetail)
# Out:
# list

# %%
new_data = []

for item in cardetail:
    # Satırları ayırarak bir liste oluşturdum
    item_list = item.split('\n')
    # Boş olan elemanları listeden çıkardım
    item_list = list(filter(None, item_list))
    # İlan tarihi ve marka değerlerini yeni bir liste olarak ekledim
    new_item = []
    for i in range(0, len(item_list), 2):
        new_item.append(item_list[i])
    # Yeni oluşan listeyi ana listede sakladım
    new_data.append(new_item)
    
# Yeni oluşan liste
print(new_data)
# Out:
# [['1.620.000 TL', 'ANKARA / GÖLBAŞI / KIZILCAŞAR MAHALLESİ', '22216901', '09 Mayıs 2023', 'Mercedes - Benz', 'C', 'C 180 AMG', '2015', '95.000 km', 'Otomatik', 'Benzin', 'Sedan', '1595 cc', '156 hp', 'Arkadan İtiş', '5,8 lt', '41 lt', '1 değişen', 'Takasa Uygun', 'Galeriden', 'Favori'], ['542.000 TL', 'KIRKLARELİ / LÜLEBURGAZ / YENİ MAHALLESİ', '22016561', '09 Mayıs 2023', 'Fiat', 'Fiorino', 'Fiorino Combi 1.4 Fire Premio', '2022', '8.700 km', 'Düz', 'Benzin', 'Camlı Van', '1368 cm3', '77 hp', '4x4', '3+1', 'Kamyonet', 'Tamamı orjinal', 'Takasa Uygun', 'Galeriden', 'Favori'], ['795.000 TL', 'ANKARA / ÇANKAYA / EMEK MAHALLESİ', '22587478', '09 Mayıs 2023', 'Nissan', 'Qashqai', '1.5 dCi Tekna Sky Pack', '2014', '148.000 km', 'Düz', 'Dizel', 'SUV', '1401 - 1600 cm3', '101 - 125 HP', 'Önden Çekiş', '1 boyalı', 'Takasa Uygun', 'Galeriden', 'Favori'], ['445.000 TL', 'YALOVA / MERKEZ / MUSTAFA KEMAL PAŞA MAHALLESİ', '22587475', '09 Mayıs 2023', 'Ford', 'Transit Courier', '1.5 TDCi Trend', '2022', '3.000 km', 'Düz', 'Dizel', 'Panel Van', '1498 cm3', '75 hp', '4x2 (Önden Çekişli)', '2+1', 'Kamyonet', 'Tamamı orjinal', 'Takasa Uygun Değil', 'Galeriden', 'Favori'], ['558.000 TL', 'YALOVA / MERKEZ / MUSTAFA KEMAL PAŞA MAHALLESİ', '22587414', '09 Mayıs 2023', 'Renault', 'Clio', '0.9 TCe Sport Tourer Joy', '2020', '42.000 km', 'Düz', 'Benzin', 'Hatchback/5', '898 cc', '90 hp', 'Önden Çekiş', '5 lt', '45 lt', 'Tamamı orjinal', 'Takasa Uygun Değil', 'Galeriden', 'Favori'], ['754.950 TL', 'KAYSERİ / KOCASİNAN / YILDIZEVLER MAHALLESİ', '22587436', '09 Mayıs 2023', 'Opel', 'Astra', '1.4 T Enjoy', '2017', '107.000 km', 'Otomatik', 'Benzin', 'Hatchback/5', '1399 cc', '150 hp', 'Önden Çekiş', '5,5 lt', '52 lt', 'Tamamı orjinal', 'Takasa Uygun', 'Galeriden', 'Favori'], ['425.000 TL', 'GİRESUN / TİREBOLU / KÖRLİMAN MAHALLESİ', '22587352', '09 Mayıs 2023', 'Opel', 'Astra', '1.3 CDTI Edition', '2012', '364.000 km', 'Düz', 'Dizel', 'Hatchback/5', '1248 cc', '95 hp', 'Önden Çekiş', '4,1 lt', '56 lt', 'Belirtilmemiş', 'Takasa Uygun Değil', 'Galeriden', 'Favori'], ['768.400 TL', 'ADIYAMAN / KAHTA / YAVUZ SELİM MAHALLESİ', '22587289', '09 Mayıs 2023', 'Ford', 'Focus', '1.6 TDCi Trend X', '2017', '89.000 km', 'Düz', 'Dizel', 'Sedan', '1560 cc', '95 hp', 'Önden Çekiş', '4,5 lt', '53 lt', 'Tamamı orjinal', 'Takasa Uygun Değil', 'Galeriden', 'Favori'], ['305.000 TL', 'İZMİR / GAZİEMİR / BEYAZEVLER MAHALLESİ', '22587178', '09 Mayıs 2023', 'Renault', 'Megane', '1.6 Dynamique', '2004', '299.000 km', 'Düz', 'LPG & Benzin', 'Hatchback/5', '1598 cc', '115 hp', 'Önden Çekiş', '6,8 lt', '60 lt', 'Belirtilmemiş', 'Takasa Uygun', 'Galeriden', 'Favori'], ['369.500 TL', 'İZMİR / ÖDEMİŞ / UMURBEY MAHALLESİ', '22587133', '09 Mayıs 2023', 'Hyundai', 'Getz', '1.5 CRDi VGT', '2010', '175.000 km', 'Düz', 'Dizel', 'Hatchback/5', '1493 cc', '110 hp', 'Önden Çekiş', '4,5 lt', '45 lt', 'Belirtilmemiş', 'Takasa Uygun Değil', 'Galeriden', 'Favori'], ['682.000 TL', 'ANTALYA / KEPEZ / KUZEYYAKA MAHALLESİ', '22587106', '09 Mayıs 2023', 'Mercedes - Benz', 'C', 'C 180 Kompressor Avantgarde', '2009', '250.000 km', 'Otomatik', 'Benzin', 'Sedan', '1796 cc', '156 hp', 'Arkadan İtiş', '8,3 lt', '66 lt', '1 değişen, 8 boyalı', 'Takasa Uygun Değil', 'Galeriden', 'Favori'], ['350.000 TL', 'ELAZIĞ / MERKEZ / SANAYİ MAHALLESİ', '22181886', '09 Mayıs 2023', 'Ford Trucks', 'Transit', '330 S', '2004', '123.000 km', 'Düz', 'Dizel', '2402 cm3', '90 hp', 'Açık Kasa', '3.001 - 5.000', 'Normal', '90 %', 'İlk Sahibi Değilim', '8,7 lt', '80 lt', 'Takasa Uygun', 'Galeriden', 'Favori'], ['845.000 TL', 'İSTANBUL / KADIKÖY / MERDİVENKÖY MAHALLESİ', '22587096', '09 Mayıs 2023', 'Mercedes - Benz', 'C', 'C 180 Kompressor BlueEfficiency Luxury', '2010', '58.000 km', 'Otomatik', 'Benzin', 'Sedan', '1597 cc', '156 hp', 'Arkadan İtiş', '6,5 lt', '66 lt', 'Belirtilmemiş', 'Takasa Uygun', 'Galeriden', 'Favori'], ['410.000 TL', 'İZMİR / BUCA / İNÖNÜ MAHALLESİ', '22587019', '09 Mayıs 2023', 'Volkswagen', 'Caddy', '1.9 TDI K ...

# %% [markdown]
# \n şeklinde birbirinden ayrılan verileri düzenledim ve başlıkları almadım.

# %%
new_data[0]
# Out:
# ['1.620.000 TL',
#  'ANKARA / GÖLBAŞI / KIZILCAŞAR MAHALLESİ',
#  '22216901',
#  '09 Mayıs 2023',
#  'Mercedes - Benz',
#  'C',
#  'C 180 AMG',
#  '2015',
#  '95.000 km',
#  'Otomatik',
#  'Benzin',
#  'Sedan',
#  '1595 cc',
#  '156 hp',
#  'Arkadan İtiş',
#  '5,8 lt',
#  '41 lt',
#  '1 değişen',
#  'Takasa Uygun',
#  'Galeriden',
#  'Favori']

# %%
new_data[0][0]
# Out:
# '1.620.000 TL'

# %% [markdown]
# Fiyatın yanındaki "TL" "." ve kilometrenin yanındaki "km" "." ifadesi daha sonrası için sıkıntı yaratacağı için basit bir şekilde bunları yok saydım.

# %%
for data in new_data:
    data[0] = data[0].replace(' TL', '')
    data[0] = data[0].replace('.', '')
    data[8] = data[8].replace(' km', '')
    data[8] = data[8].replace('.', '')
new_data
    #listedeki bütün fiyatların sonundaki TL stringini kaldırmaya çalışıyorum**
# Out:
# [['1620000',
#   'ANKARA / GÖLBAŞI / KIZILCAŞAR MAHALLESİ',
#   '22216901',
#   '09 Mayıs 2023',
#   'Mercedes - Benz',
#   'C',
#   'C 180 AMG',
#   '2015',
#   '95000',
#   'Otomatik',
#   'Benzin',
#   'Sedan',
#   '1595 cc',
#   '156 hp',
#   'Arkadan İtiş',
#   '5,8 lt',
#   '41 lt',
#   '1 değişen',
#   'Takasa Uygun',
#   'Galeriden',
#   'Favori'],
#  ['542000',
#   'KIRKLARELİ / LÜLEBURGAZ / YENİ MAHALLESİ',
#   '22016561',
#   '09 Mayıs 2023',
#   'Fiat',
#   'Fiorino',
#   'Fiorino Combi 1.4 Fire Premio',
#   '2022',
#   '8700',
#   'Düz',
#   'Benzin',
#   'Camlı Van',
#   '1368 cm3',
#   '77 hp',
#   '4x4',
#   '3+1',
#   'Kamyonet',
#   'Tamamı orjinal',
#   'Takasa Uygun',
#   'Galeriden',
#   'Favori'],
#  ['795000',
#   'ANKARA / ÇANKAYA / EMEK MAHALLESİ',
#   '22587478',
#   '09 Mayıs 2023',
#   'Nissan',
#   'Qashqai',
#   '1.5 dCi Tekna Sky Pack',
#   '2014',
#   '148000',
#   'Düz',
#   'Dizel',
#   'SUV',
#   '1401 - 1600 cm3',
#   '101 - 125 HP',
#   'Önden Çekiş',
#   '1 boyalı',
#   'Takasa Uygun',
#   'Galeriden',
#   'Favori'],
#  ['445000',
#   'YALOVA / MERKEZ / MUSTAFA KEMAL PAŞA MAHALLESİ',
#   '22587475',
#   '09 Mayıs 2023',
#   'Ford',
#   'Transit Courier',
#   '1.5 TDCi Trend',
#   '2022',
#   '3000',
#   'Düz',
#   'Dizel',
#   'Panel Van',
#   '1498 cm3',
#   '75 hp',
#   '4x2 (Önden Çekişli)',
#   '2+1',
#   'Kamyonet',
#   'Tamamı orjinal',
#   'Takasa Uygun Değil',
#   'Galeriden',
#   'Favori'],
#  ['558000',
#   'YALOVA / MERKEZ / MUSTAFA KEMAL PAŞA MAHALLESİ',
#   '22587414',
#   '09 Mayıs 2023',
#   'Renault',
#   'Clio',
#   '0.9 TCe Sport Tourer Joy',
#   '2020',
#   '42000',
#   'Düz',
#   'Benzin',
#   'Hatchback/5',
#   '898 cc',
#   '90 hp',
#   'Önden Çekiş',
#   '5 lt',
#   '45 lt',
#   'Tamamı orjinal',
#   'Takasa Uygun Değil',
#   'Galeriden',
#   'Favori'],
#  ['754950',
#   'KAYSERİ / KOCASİNAN / YILDIZEVLER MAHALLESİ',
#   '22587436',
#   '09 Mayıs 2023',
#   'Opel',
#   'Astra',
#   '1.4 T Enjoy',
#   '2017',
#   '107000',
#   'Otomatik',
#   'Benzin',
#   'Hatchback/5',
#   '1399 cc',
#   '150 hp',
#   'Önden Çekiş',
#   '5,5 lt',
#   '52 lt',
#   'Tamamı orjinal',
#   'Takasa Uygun',
#   'Galeriden',
#   'Favori'],
#  ['425000',
#   'GİRESUN / TİREBOLU / KÖRLİMAN MAHALLESİ',
#   '22587352',
#   '09 Mayıs 2023',
#   'Opel',
#   'Astra',
#   '1.3 CDTI Edition',
#   '2012',
#   '364000',
#   'Düz',
#   'Dizel',
#   'Hatchback/5',
#   '1248 cc',
#   '95 hp',
#   'Önden Çekiş',
#   '4,1 lt',
#   '56 lt',
#   'Belirtilmemiş',
#   'Takasa Uygun Değil',
#   'Galeriden',
#   'Favori'],
#  ['768400',
#   'ADIYAMAN / KAHTA / YAVUZ SELİM MAHALLESİ',
#   '22587289',
#   '09 Mayıs 2023',
#   'Ford',
#   'Focus',
#   '1.6 TDCi Trend X',
#   '2017',
#   '89000',
#   'Düz',
#   'Dizel',
#   'Sedan',
#   '1560 cc',
#   '95 hp',
#   'Önden Çekiş',
#   '4,5 lt',
#   '53 lt',
#   'Tamamı orjinal',
#   'Takasa Uygun Değil',
#   'Galeriden',
#   'Favori'],
#  ['305000',
#   'İZMİR / GAZİEMİR / BEYAZEVLER MAHALLESİ',
#   '22587178',
#   '09 Mayıs 2023',
#   'Renault',
#   'Megane',
#   '1.6 Dynamique',
#   '2004',
#   '299000',
#   'Düz',
#   'LPG & Benzin',
#   'Hatchback/5',
#   '1598 cc',
#   '115 hp',
#   'Önden Çekiş',
#   '6,8 lt',
#   '60 lt',
#   'Belirtilmemiş',
#   'Takasa Uygun',
#   'Galeriden',
#   'Favori'],
#  ['369500',
#   'İZMİR / ÖDEMİŞ / UMURBEY MAHALLESİ',
#   '22587133',
#   '09 Mayıs 2023',
#   'Hyundai',
#   'Getz',
#   '1.5 CRDi VGT',
#   '2010',
#   '175000',
#   'Düz',
#   'Dizel',
#   'Hatchback/5',
#   '1493 cc',
#   '110 hp',
#   'Önden Çekiş',
#   '4,5 lt',
#   '45 lt',
#   'Belirtilmemiş',
#   'Takasa Uygun Değil',
#   'Galeriden',
#   'Favori'],
#  ['682000',
#   'ANTALYA / KEPEZ / KUZEYYAKA MAHALLESİ',
#   '22587106',
#   '09 Mayıs 2023',
#   'Mercedes - Benz',
#   'C',
#   'C 180 Kompressor Avantgarde',
#   '2009',
#   '250000',
#   'Otomatik',
#   'Benzin',
#   'Sedan',
#   '1796 cc',
#   '156 hp',
#   'Arkadan İtiş',
#   '8,3 lt',
#   '66 lt',
#   '1 değişen, 8 boyalı',
#   'Takasa Uygun Değil',
#   'Galeriden',
#   'Favori'],
#  ['350000',
#   'ELAZIĞ / MERKEZ / SANAYİ MAHALLESİ',
#   '22181886',
#   '09 Mayıs 2023',
#   'Ford Trucks',
#   'Transit',
#   '330 S',
#   '2004',
#   '123000',
#   'Düz',
#   'Dizel',
#   '2402 cm3',
#   '90 hp',
#   'Açık Kasa',
#   '3.001 - 5.000',
#   'Normal',
#   '90 %',
#   'İlk Sahibi Değilim',
#   '8,7 lt',
#   '80 lt',
#   'Takasa Uygun',
#   'Galeriden',
#   'Favori'],
#  ['845000',
#   'İSTANBUL / KADIKÖY / MERDİVENKÖY MAHALLESİ',
#   '22587096',
#   '09 Mayıs 2023',
#   'Mercedes - Benz',
#   'C',
#   'C 180 Kompressor BlueEfficiency Luxury',
#   '2010',
#   '58000',
#   'Otomatik',
#   'Benzin',
#   'Sedan',
#   '1597 cc',
#   '156 hp',
#   'Arkadan İtiş',
#   '6,5 lt',
#   '66 lt',
#   'Belirtilmemiş',
#   'Takasa Uygun',
#   'Galeriden',
#   'Favori'],
#  ['410000',
#   'İZMİR / BUCA / İNÖNÜ MAHALLESİ',
#   '22587019',
#   '09 Mayıs 2023',
#   'Volkswagen',
#   'Caddy',
#   '1.9 TDI Kombi',
#   '2008',
#   '220000',
#   'Yarı Otomatik',
#   'Dizel',
#   'Camlı Van',
#   '1896 cm3',
#   '105 hp',
#   '-',
#   '4+1',
#   'Kamyonet',
#   'Belirtilmemiş',
#   'Takasa Uygun',
#   'Galeriden',
#   'Favori'],
#  ['405000',
#   'ISPARTA / MERKEZ / DAVRAZ MAHALLESİ',
#   '22587060',
#   '09 Mayıs 2023',
#   'Fiat',
#   'Fiorino',
#   'Fiorino Combi 1.4 Fire Safeline',
#   '2017',
#   '127600',
#   'Düz',
#   'LPG & Benzin',
#   'Camlı Van',
#   '1368 cm3',
#   '77 hp',
#   '4x2 (Önden Çekişli)',
#   '4+1',
#   'Kamyonet',
#   'Belirtilmemiş',
#   'Takasa Uygun',
#   'Galeriden',
#   'Favori'],
#  ['365000',
#   'MUĞLA / FETHİYE / KARAÇULHA MAHALLESİ',
#   '22568183',
#   '09 Mayıs 2023',
#   'Fiat',
#   'Doblo',
#   'Doblo Combi 1.3 Multijet Maxi Easy',
#   '2016',
#   '300500',
#   'Düz',
#   'Dizel',
#   'Camlı Van',
#   '1248 cm3',
#   '90 hp',
#   '4x2 (Önden Çekişli)',
#   '4+1',
#   'Kamyonet',
#   'Belirtilmemiş',
#   'Takasa Uygun',
#   'Galeriden',
#   'Favori'],
#  ['618000',
#   'İSTANBUL / BAĞCILAR / 100. YIL MAHALLESİ',
#   '22586961',
#   '09 Mayıs 2023',
#   'Volkswagen',
#   'Jetta',
#   '1.2 TSi Trendline',
#   '2014',
#   '161800',
#   'Yarı Otomatik',
#   'Benzin',
#   'Sedan',
#   '1197 cc',
#   '105 hp',
#   'Önden Çekiş',
#   '5,4 lt',
#   '55 lt',
#   '1 değişen, 3 boyalı',
#   'Takasa Uygun',
#   'Galeriden',
#   'Favori'],
#  ['348500',
#   'İZMİR / BALÇOVA / ÇETİN EMEÇ MAHALLESİ',
#   '22586919',
#   '09 Mayıs 2023',
#   'Renault',
#   'Symbol',
#   '1.5 dCi Authentique',
#   '2011',
#   '154000',
#   'Düz',
#   'Dizel',
#   'Sedan',
#   '1461 cc',
#   '65 hp',
#   'Önden Çekiş',
#   '4,5 lt',
#   '50 lt',
#   'Belirtilmemiş',
#   'Takasa Uygun Değil',
#   'Galeriden',
#   'Favori'],
#  ['430000',
#   'İSTANBUL / TUZLA / ŞİFA MAHALLESİ',
#   '22586812',
#   '09 Mayıs 2023',
#   'Renault',
#   'Clio',
#   '1.5 dCi Joy',
#   '2014',
#   '205000',
#   'Düz',
#   'Dizel',
#   'Hatchback/5',
#   '1461 cc',
#   '75 hp',
#   'Önden Çekiş',
#   '3,6 lt',
#   '45 lt',
#   '5 boyalı',
#   'Takasa Uygun',
#   'Galeriden',
#   'Favori'],
#  ['345000',
#   'İZMİR / GAZİEMİR / BEYAZEVLER MAHALLESİ',
#   '22457603',
#   '09 Mayıs 2023',
#   'Renault',
#   'Symbol',
#   '1.5 dCi Expression',
#   '2009',
#   '213000',
#   'Düz',
#   'Dizel',
#   'Sedan',
#   '1461 cc',
#   '85 hp',
#   'Önden Çekiş',
#   '4,3 lt',
#   '50 lt',
#   'Belirtilmemiş',
#   'Takasa Uygun',
#   'Galeriden',
#   'Favori'],
#  ['675000',
#   'ANKARA / YENİMAHALLE / PAMUKLAR MAHALLESİ',
#   '22586715',
#   '09 Mayıs 2023',
#   'Peugeot',
#   '308',
#   '1.6 BlueHdi Active',
#   '2017',
#   '170000',
#   'Otomatik',
#   'Dizel',
#   'Hatchback/5',
#   '1560 cc',
#   '122 hp',
#   'Önden Çekiş',
#   '3,7 lt',
#   '53 lt',
#   '2 boyalı',
#   'Takasa Uygun Değil',
#   'Galeriden',
#   'Favori'],
#  ['238750',
#   'BURSA / İNEGÖL / ŞEHİTLER MAHALLESİ',
#   '22586730',
#   '09 Mayıs 2023',
#   'Fiat',
#   'Albea',
#   '1.2 Active',
#   '2004',
#   '190099',
#   'Düz',
#   'Benzin',
#   'Sedan',
#   '1242 cc',
#   '80 hp',
#   'Önden Çekiş',
#   '7 lt',
#   '47 lt',
#   'Tamamı boyalı',
#   '-',
#   'Galeriden',
#   'Favori'],
#  ['899900',
#   'DENİZLİ / SARAYKÖY / BEYLERBEYİ MAHALLESİ',
#   '21930033',
#   '09 Mayıs 2023',
#   'Volkswagen',
#   'Passat',
#   '1.4 TSi BlueMotion Highline',
#   '2014',
#   '145000',
#   'Yarı Otomatik',
#   'Benzin',
#   'Sedan',
#   '1390 cc',
#   '160 hp',
#   'Önden Çekiş',
#   '6,7 lt',
#   '70 lt',
#   'Belirtilmemiş',
#   'Takasa Uygun Değil',
#   'Galeriden',
#   'Favori'],
#  ['440000',
#   'KONYA / SELÇUKLU / FATİH MAHALLESİ',
#   '22447352',
#   '09 Mayıs 2023',
#   'Renault',
#   'Master',
#   '2.3 DCi',
#   '2012',
#   '325000',
#   'Düz',
#   'Dizel',
#   '2300 cm3',
#   '125 hp',
#   'Tenteli Kasa',
#   '1.501 - 3.000',
#   'Normal',
#   '100 %',
#   'İlk Sahibi Değilim',
#   'Takasa Uygun Değil',
#   'Galeriden',
#   'Favori'],
#  ['825000',
#   'AKSARAY / MERKEZ / HACILARHARMANI MAHALLESİ',
#   '22586475',
#   '09 Mayıs 2023',
#   'Ford',
#   'Tourneo Courier',
#   '1.5 TDCi Titanium Plus',
#   '2023',
#   '600',
#   'Düz',
#   'Dizel',
#   'Camlı Van',
#   '1498 cm3',
#   '100 hp',
#   '4x2 (Önden Çekişli)',
#   '3+1',
#   'Kamyonet',
#   'Belirtilmemiş',
#   'Takasa Uygun',
#   'Galeriden',
#   'Favori'],
#  ['1599000',
#   'ANTALYA / MURATPAŞA / DEMİRCİKARA MAHALLESİ',
#   '22586476',
#   '09 Mayıs 2023',
#   'BMW',
#   '1 Serisi',
#   '118i Sport Line',
#   '2022',
#   '12000',
#   'Otomatik',
#   'Benzin',
#   'Hatchback/5',
#   '1499 cc',
#   '140 hp',
#   'Önden Çekiş',
#   '6 lt',
#   '42 lt',
#   'Tamamı orjinal',
#   'Takasa Uygun',
#   'Galeriden',
#   'Favori'],
#  ['675000',
#   'GAZİANTEP / ŞEHİTKAMİL / KARACAAHMET MAHALLESİ',
#   '22586432',
#   '09 Mayıs 2023',
#   'Mercedes - Benz',
#   'C',
#   'C 180 Kompressor BlueEFFICIENCY AMG',
#   '2010',
#   '250000',
#   'Otomatik',
#   'LPG & Benzin',
#   'Sedan',
#   '1597 cc',
#   '156 hp',
#   'Arkadan İtiş',
#   '6,5 lt',
#   '66 lt',
#   'Tamamı orjinal',
#   'Takasa Uygun',
#   'Galeriden',
#   'Favori'],
#  ['615000',
#   'ANTALYA / KUMLUCA / GÖKSU MAHALLESİ',
#   '21709979',
#   '09 Mayıs 2023',
#   'Volkswagen',
#   'Polo',
#   '1.4 TDi Comfortline',
#   '2014',
#   '28000',
#   'Düz',
#   'Dizel',
#   'Hatchback/5',
#   '1422 cc',
#   '90 hp',
#   'Önden Çekiş',
#   '3,4 lt',
#   '45 lt',
#   'Belirtilmemiş',
#   'Takasa Uygun',
#   'Galeriden',
#   'Favori'],
#  ['920000',
#   'OSMANİYE / MERKEZ / ŞİRİNEVLER MAHALLESİ',
#   '22586197',
#   '09 Mayıs 2023',
#   'Volkswagen',
#   'Passat',
#   '1.6 TDi BlueMotion Comfortline',
#   '2015',
#   '327500',
#   'Yarı Otomatik',
#   'Dizel',
#   'Sedan',
#   '1598 cc',
#   '120 hp',
#   'Önden Çekiş',
#   '4 lt',
#   '66 lt',
#   'Belirtilmemiş',
#   'Takasa Uygun',
#   'Galeriden',
#   'Favori'],
#  ['850000',
#   'KONYA / KARATAY / FEVZİÇAKMAK MAHALLESİ',
#   '22125672',
#   '09 Mayıs 2023',
#   'Volkswagen',
#   'Passat',
#   '1.6 TDi BlueMotion Impression',
#   '2017',
#   '213000',
#   'Yarı Otomatik',
#   'Dizel',
#   'Sedan',
#   '1598 cc',
#   '120 hp',
#   'Önden Çekiş',
#   '4 lt',
#   '59 lt',
#   '1 değişen, 9 boyalı',
#   'Takasa Uygun Değil',
#   'Galeriden',
#   'Favori'],
#  ['323000',
#   'ORDU / FATSA / MUSTAFAKEMALPAŞA MAHALLESİ',
#   '22549990',
#   '09 Mayıs 2023',
#   'Renault',
#   'Megane',
#   '1.5 dCi Dynamique',
#   '2005',
#   '235750',
#   'Düz',
#   'Dizel',
#   'Sedan',
#   '1461 cc',
#   '80 hp',
#   'Önden Çekiş',
#   '4,6 lt',
#   '60 lt',
#   '5 boyalı',
#   'Takasa Uygun Değil',
#   'Galeriden',
#   'Favori'],
#  ['515000',
#   'BURSA / GEMLİK / EŞREF DİNÇER MAHALLESİ',
#   '22586124',
#   '09 Mayıs 2023',
#   'Volkswagen',
#   'Caddy',
#   '1.6 TDI Trendline',
#   '2011',
#   '227000',
#   'Yarı Otomatik',
#   'Dizel',
#   'Camlı Van',
#   '1598 cm3',
#   '102 hp',
#   '4x2 (Arkadan İtişli)',
#   '4+1',
#   'Kamyonet',
#   '5 boyalı',
#   'Takasa Uygun',
#   'Galeriden',
#   'Favori'],
#  ['485000',
#   'ŞANLIURFA / SURUÇ / SARAYALTI MAHALLESİ',
#   '22117111',
#   '09 Mayıs 2023',
#   'Mercedes - Benz',
#   'Sprinter',
#   '315 CDI',
#   '2009',
#   '730000',
#   'Düz',
#   'Dizel',
#   '2148 cm3',
#   '150 hp',
#   'Beyaz',
#   '16+1',
#   'Normal Tavan',
#   'İlk Sahibi Değilim',
#   '75 lt',
#   'Takasa Uygun',
#   'Galeriden',
#   'Favori'],
#  ['985000',
#   'BALIKESİR / EDREMİT / CENNETAYAĞI MAHALLESİ',
#   '22118110',
#   '09 Mayıs 2023',
#   'Volkswagen',
#   'Passat',
#   '1.6 TDi BlueMotion Comfortline',
#   '2016',
#   '168000',
#   'Yarı Otomatik',
#   'Dizel',
#   'Sedan',
#   '1598 cc',
#   '120 hp',
#   'Önden Çekiş',
#   '4 lt',
#   '66 lt',
#   'Belirtilmemiş',
#   'Takasa Uygun',
#   'Galeriden',
#   'Favori'],
#  ['1475000',
#   'UŞAK / MERKEZ / DURAK MAHALLESİ',
#   '22586003',
#   '09 Mayıs 2023',
#   'Mercedes - Benz',
#   'E',
#   '180 AMG',
#   '2013',
#   '153000',
#   'Otomatik',
#   'Benzin',
#   'Sedan',
#   '1595 cc',
#   '156 hp',
#   'Arkadan İtiş',
#   '6,6 lt',
#   '59 lt',
#   'Tamamı orjinal',
#   'Takasa Uygun',
#   'Galeriden',
#   'Favori'],
#  ['1045000',
#   'İSTANBUL / BAĞCILAR / MAHMUTBEY MAHALLESİ',
#   '22446906',
#   '09 Mayıs 2023',
#   'Peugeot',
#   '2008',
#   '1.5 BlueHDI Active',
#   '2020',
#   '36000',
#   'Otomatik',
#   'Dizel',
#   'Crossover',
#   '1499 cc',
#   '132 hp',
#   'Önden Çekiş',
#   '3,8 lt',
#   '41 lt',
#   'Belirtilmemiş',
#   'Takasa Uygun',
#   'Galeriden',
#   'Favori'],
#  ['1148000',
#   'KİLİS / MERKEZ / İZZETTİN İYİGÜN PAŞA MAHALLESİ',
#   '22585911',
#   '09 Mayıs 2023',
#   'Peugeot',
#   '3008',
#   '1.5 BlueHDI Allure Selection',
#   '2019',
#   '82000',
#   'Otomatik',
#   'Dizel',
#   'Crossover',
#   '1499 cc',
#   '132 hp',
#   'Önden Çekiş',
#   '4,1 lt',
#   '53 lt',
#   'Belirtilmemiş',
#   'Takasa Uygun',
#   'Galeriden',
#   'Favori'],
#  ['529000',
#   'ANKARA / ÇANKAYA / BİRLİK MAHALLESİ',
#   '22364438',
#   '09 Mayıs 2023',
#   'Volvo',
#   'S40',
#   '1.6 D',
#   '2011',
#   '218000',
#   'Düz',
#   'Dizel',
#   'Sedan',
#   '1560 cc',
#   '115 hp',
#   'Önden Çekiş',
#   '4,3 lt',
#   '55 lt',
#   'Tamamı orjinal',
#   'Takasa Uygun',
#   'Galeriden',
#   'Favori'],
#  ['745000',
#   'BURSA / GEMLİK / EŞREF DİNÇER MAHALLESİ',
#   '22585780',
#   '09 Mayıs 2023',
#   'Fiat',
#   'Egea',
#   '1.3 Multijet Easy Plus',
#   '2022',
#   '6100',
#   'Düz',
#   'Dizel',
#   'Sedan',
#   '1248 cc',
#   '95 hp',
#   'Önden Çekiş',
#   '4,1 lt',
#   '50 lt',
#   'Tamamı orjinal',
#   'Takasa Uygun',
#   'Galeriden',
#   'Favori'],
#  ['749900',
#   'İSTANBUL / ATAŞEHİR / KÜÇÜKBAKKALKÖY MAHALLESİ',
#   '21706544',
#   '09 Mayıs 2023',
#   'Mercedes - Benz',
#   'C',
#   'C 180 Kompressor BlueEfficiency Luxury',
#   '2010',
#   '192000',
#   'Otomatik',
#   'LPG & Benzin',
#   'Sedan',
#   '1597 cc',
#   '156 hp',
#   'Arkadan İtiş',
#   '6,5 lt',
#   '66 lt',
#   'Belirtilmemiş',
#   'Takasa Uygun Değil',
#   'Galeriden',
#   'Favori']]

# %%
new_data[0]
# Out:
# ['1620000',
#  'ANKARA / GÖLBAŞI / KIZILCAŞAR MAHALLESİ',
#  '22216901',
#  '09 Mayıs 2023',
#  'Mercedes - Benz',
#  'C',
#  'C 180 AMG',
#  '2015',
#  '95000',
#  'Otomatik',
#  'Benzin',
#  'Sedan',
#  '1595 cc',
#  '156 hp',
#  'Arkadan İtiş',
#  '5,8 lt',
#  '41 lt',
#  '1 değişen',
#  'Takasa Uygun',
#  'Galeriden',
#  'Favori']

# %%
type(new_data)
# Out:
# list

# %% [markdown]
# MongoDB kütüphanelerini import ediyorum

# %%
from pymongo import MongoClient
from dotenv import load_dotenv, find_dotenv
import os
import pprint
load_dotenv(find_dotenv())

#MongoDB için gerekli kütüphaneler
# Out:
# True

# %% [markdown]
# MongoDb database'imi bağlıyorum.

# %%
password = os.environ.get("MONGODB_PWD")
connection_string = f"mongodb+srv://emirhanbal:{password}@graduation.r68pz0b.mongodb.net/?retryWrites=true&w=majority"
client = MongoClient(connection_string)

#MONGODB ile kodumu ilişkilendirme adımı. burada database'imi bağlıyorum.

# %% [markdown]
# Database'de dictionary tipinde local variable oluşturup database'e verileri aktarıyorum.

# %%
import pymongo

db = client["mydatabase"]
collection = db["mycollection"]

for item in new_data:
    data = {
        "Fiyat":item[0],
        "Adres": item[1],
        "ilan Numarası": item[2],
        "ilan Tarihi" : item[3],
        "Marka" : item[4],
        "Seri" : item[5],
        "Model" : item[6],
        "Yıl" : item[7],
        "Kilometre" : item[8],
        "Vites Tipi" : item[9],
        "Yakıt Tipi": item[10],
        "Kasa Tipi" : item[11],
        "Motor Hacmi" : item[12],
        "Motor Gücü" : item[13],
        "Çekiş" : item[14],
        "Ort. Yakıt Tüketimi" : item[15],
        "Yakıt Deposu" : item[16],
        "Boya-değişen" : item[17],
        "Takasa Uygun" : item[18]
        #"Kimden" : item[19]
        
    }
    collection.insert_one(data)
    
#local variable ve dictionary. burada data tiplerimi ve karşılığında ne olmasını istediğimi belirtiyorum.

# %%
dbs = client.list_database_names()
print(dbs)
# Out:
# ['mydatabase', 'test', 'admin', 'local']

# %%
collection.find_one()
# Out:
# {'_id': ObjectId('645a3dbb3eb6671c7e1205cd'),
#  'Fiyat': '1620000',
#  'Adres': 'ANKARA / GÖLBAŞI / KIZILCAŞAR MAHALLESİ',
#  'ilan Numarası': '22216901',
#  'ilan Tarihi': '09 Mayıs 2023',
#  'Marka': 'Mercedes - Benz',
#  'Seri': 'C',
#  'Model': 'C 180 AMG',
#  'Yıl': '2015',
#  'Kilometre': '95000',
#  'Vites Tipi': 'Otomatik',
#  'Yakıt Tipi': 'Benzin',
#  'Kasa Tipi': 'Sedan',
#  'Motor Hacmi': '1595 cc',
#  'Motor Gücü': '156 hp',
#  'Çekiş': 'Arkadan İtiş',
#  'Ort. Yakıt Tüketimi': '5,8 lt',
#  'Yakıt Deposu': '41 lt',
#  'Boya-değişen': '1 değişen',
#  'Takasa Uygun': 'Takasa Uygun'}

# %% [markdown]
# Basit bir filtreleme yapıyorum.

# %%
denemeSorgusu = {"Marka" : "Fiat"}
#Marka fiyat filtreleyebilmek için deneme sorgusu

# %%
Marka = input()
Seri = input()
#kullanıcıdan input almak için örnek adım
# Out:
# Mercedes - Benz
# C

# %%
denemeSorgusu = {"Marka" : Marka, "Seri" : Seri}
#sorguyu yazdırdım

# %%
for i in collection.find(denemeSorgusu, {"_id":0}):
    print(i)
#kullanıcının inputlarına göre datasetimi sorguladım ve sonuçları doğru ve eksiksiz bir biçimde verdi.
# Out:
# {'Fiyat': '1620000', 'Adres': 'ANKARA / GÖLBAŞI / KIZILCAŞAR MAHALLESİ', 'ilan Numarası': '22216901', 'ilan Tarihi': '09 Mayıs 2023', 'Marka': 'Mercedes - Benz', 'Seri': 'C', 'Model': 'C 180 AMG', 'Yıl': '2015', 'Kilometre': '95000', 'Vites Tipi': 'Otomatik', 'Yakıt Tipi': 'Benzin', 'Kasa Tipi': 'Sedan', 'Motor Hacmi': '1595 cc', 'Motor Gücü': '156 hp', 'Çekiş': 'Arkadan İtiş', 'Ort. Yakıt Tüketimi': '5,8 lt', 'Yakıt Deposu': '41 lt', 'Boya-değişen': '1 değişen', 'Takasa Uygun': 'Takasa Uygun'}
# {'Fiyat': '682000', 'Adres': 'ANTALYA / KEPEZ / KUZEYYAKA MAHALLESİ', 'ilan Numarası': '22587106', 'ilan Tarihi': '09 Mayıs 2023', 'Marka': 'Mercedes - Benz', 'Seri': 'C', 'Model': 'C 180 Kompressor Avantgarde', 'Yıl': '2009', 'Kilometre': '250000', 'Vites Tipi': 'Otomatik', 'Yakıt Tipi': 'Benzin', 'Kasa Tipi': 'Sedan', 'Motor Hacmi': '1796 cc', 'Motor Gücü': '156 hp', 'Çekiş': 'Arkadan İtiş', 'Ort. Yakıt Tüketimi': '8,3 lt', 'Yakıt Deposu': '66 lt', 'Boya-değişen': '1 değişen, 8 boyalı', 'Takasa Uygun': 'Takasa Uygun Değil'}
# {'Fiyat': '845000', 'Adres': 'İSTANBUL / KADIKÖY / MERDİVENKÖY MAHALLESİ', 'ilan Numarası': '22587096', 'ilan Tarihi': '09 Mayıs 2023', 'Marka': 'Mercedes - Benz', 'Seri': 'C', 'Model': 'C 180 Kompressor BlueEfficiency Luxury', 'Yıl': '2010', 'Kilometre': '58000', 'Vites Tipi': 'Otomatik', 'Yakıt Tipi': 'Benzin', 'Kasa Tipi': 'Sedan', 'Motor Hacmi': '1597 cc', 'Motor Gücü': '156 hp', 'Çekiş': 'Arkadan İtiş', 'Ort. Yakıt Tüketimi': '6,5 lt', 'Yakıt Deposu': '66 lt', 'Boya-değişen': 'Belirtilmemiş', 'Takasa Uygun': 'Takasa Uygun'}
# {'Fiyat': '675000', 'Adres': 'GAZİANTEP / ŞEHİTKAMİL / KARACAAHMET MAHALLESİ', 'ilan Numarası': '22586432', 'ilan Tarihi': '09 Mayıs 2023', 'Marka': 'Mercedes - Benz', 'Seri': 'C', 'Model': 'C 180 Kompressor BlueEFFICIENCY AMG', 'Yıl': '2010', 'Kilometre': '250000', 'Vites Tipi': 'Otomatik', 'Yakıt Tipi': 'LPG & Benzin', 'Kasa Tipi': 'Sedan', 'Motor Hacmi': '1597 cc', 'Motor Gücü': '156 hp', 'Çekiş': 'Arkadan İtiş', 'Ort. Yakıt Tüketimi': '6,5 lt', 'Yakıt Deposu': '66 lt', 'Boya-değişen': 'Tamamı orjinal', 'Takasa Uygun': 'Takasa Uygun'}
# {'Fiyat': '749900', 'Adres': 'İSTANBUL / ATAŞEHİR / KÜÇÜKBAKKALKÖY MAHALLESİ', 'ilan Numarası': '21706544', 'ilan Tarihi': '09 Mayıs 2023', 'Marka': 'Mercedes - Benz', 'Seri': 'C', 'Model': 'C 180 Kompressor BlueEfficiency Luxury', 'Yıl': '2010', 'Kilometre': '192000', 'Vites Tipi': 'Otomatik', 'Yakıt Tipi': 'LPG & Benzin', 'Kasa Tipi': 'Sedan', 'Motor Hacmi': '1597 cc', 'Motor Gücü': '156 hp', 'Çekiş': 'Arkadan İtiş', 'Ort. Yakıt Tüketimi': '6,5 lt', 'Yakıt Deposu': '66 lt', 'Boya-değişen': 'Belirtilmemiş', 'Takasa Uygun': 'Takasa Uygun Değil'}

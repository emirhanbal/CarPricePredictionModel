# %% [markdown]
# # CAR PRICE PREDICTION MODEL #MAIN

# %%
from selenium import webdriver
from time import sleep
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

##KUTUPHANELERI IMPORT ETTIK VE KOMUT ISTEMINDEN MODULLERI YUKLEDIK

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
driver.set_window_size(1250,740)
driver.set_window_position(0,0)

##CHROME DRIVERIMIZI YUKLEDIK

#LINKIMIZI BELIRLEDIK HER SAYFA PAGE2-3 DİYE GİTTİĞİ İÇİN PAGE NUMBERS BELIRLEDIK
mainLink = "https://www.arabam.com/ikinci-el"
page_numbers = range(2, 4)
#Şimdilik 2 sayfa üzerinde çalışmak için 2,4 belirledim

#BOS BIR LISTE OLUSTURDUM DATALARI BURADA TUTMAK ICIN
linklist = []

#HER SAYFADA TEK TEK DEVAM EDEBILSIN DIYE PAGE NUMBERS BELIRLEDIM BUNA GÖRE URL DUZENLEYIP O URLYE GIDECEK
#ZATEN URL BELLİ BİR DÜZENDE DEVAM EDİYOR.
for number in page_numbers:
    url = mainLink + '?page=' + str(number)
    driver.get(url)
    sleep(2)
#FONKSIYON OLARAK TAGNAME A OLAN BLOĞUN İÇİNDEKİ LİNKLERİ ALACAK BIR FOR DONGUSU DUZENLEDIM
    def get_links(driver, xpath):
        a = driver.find_element(By.XPATH, '//*[@id="js-hook-missing-space-content"]/div[2]/div[2]')
        lnks = a.find_elements(By.TAG_NAME, "a")
        for lnk in lnks:
            href = lnk.get_attribute("href")
            if href and href not in linklist:
                linklist.append(href)
        return linklist
    #HER LINKTEN 7 ADET OLDUĞU ICIN LISTENIN ICINDE VAR MI VARSA ALMA YOKSA AL GIBI BIR IF ELSE DUZENLEDIM (HER LINKTEN BIR TANE OLMASI ICIN)
    linklist = get_links(driver, '//*[@id="js-hook-missing-space-content"]/div[2]/div[2]')
    
print(linklist)
len(linklist)
# Out:
# ['https://www.arabam.com/ilan/sahibinden-satilik-jeep-grand-cherokee-3-0-crd-summit/sahibinden-jeep-grand-cherokee-3-0-crd-summit-2013-model/22581815', 'https://www.arabam.com/ilan/galeriden-satilik-seat-leon-1-4-tsi-fr/os-cardan-2016-seat-leon-fr-1-4-tsi-ozel-plakali-masrafsiz/22581980', 'https://www.arabam.com/ilan/galeriden-satilik-fiat-palio-1-4-hl/fiat-palio-1-4-hl-1998-degisensiz-klimali/22581944', 'https://www.arabam.com/ilan/galeriden-satilik-volkswagen-passat-1-6-tdi-bluemotion-comfortline/dincerler-2018-passat-comfortline-hatasiz-82-000km/22581936', 'https://www.arabam.com/ilan/galeriden-satilik-bmw-3-serisi-320i-ed-40th-year-edition/ozgulden-hatasiz-boyasiz-tramersiz-320i-ed-40-yil-ici-taba-deri/21588401', 'https://www.arabam.com/ilan/galeriden-satilik-volkswagen-passat-1-4-tsi-comfortline/ozgulden-orjinal-1-4-tsi-comfortline-145-bin-km-de-dsg-122-hp/22457858', 'https://www.arabam.com/ilan/galeriden-satilik-ford-focus-1-6-tdci-titanium/ozgulden-hatasiz-cam-gibi-1-6-tdci-titanium-110-luk-focus/22394222', 'https://www.arabam.com/ilan/galeriden-satilik-ford-tourneo-courier-1-5-tdci-delux/galeriden-ford-tourneo-courier-1-5-tdci-delux-2020-model-ankara/22537353', 'https://www.arabam.com/ilan/galeriden-satilik-volkswagen-passat-1-8-trendline/galeriden-volkswagen-passat-1-8-trendline-2000-model-van/22531897', 'https://www.arabam.com/ilan/galeriden-satilik-fiat-fiorino-combi-1-3-multijet-emotion/balibeyden-fiorino-1-3-multijet-emotion-2010-model-agri/22530211', 'https://www.arabam.com/ilan/galeriden-satilik-daf-105/omeroglu-otomotiv-den-satilik-daf-xf-460-full-pazarliksiz/21731414', 'https://www.arabam.com/ilan/galeriden-satilik-opel-vivaro-1-9-dti/galeriden-opel-vivaro-1-9-dti-2007-model-sirnak/22581842', 'https://www.arabam.com/ilan/galeriden-satilik-bmw-3-serisi-320d-premium/bes-motors-farkiyla-hatasiz-ayarinda-e90/22581837', 'https://www.arabam.com/ilan/galeriden-satilik-renault-megane-1-5-dci-touch/galeriden-renault-megane-1-5-dci-2012-model-trabzon/22428217', 'https://www.arabam.com/ilan/galeriden-satilik-dacia-duster-1-3-tce-comfort/2019-duster/22293988', 'https://www.arabam.com/ilan/galeriden-satilik-bmw-3-serisi-320i/ozturk-cars-2000-model-320i-emsalsiz/22302909', 'https://www.arabam.com/ilan/galeriden-satilik-volkswagen-golf-1-6-tdi-bluemotion-comfortline/hatasiz-2017-golf-7-1-6-tdi-110-bg-dsg-lansman-77-bin-km/22406234', 'https://www.arabam.com/ilan/galeriden-satilik-volkswagen-transporter-2-5-tdi-camli-van/galeriden-volkswagen-transporter-2-5-tdi-camli-van-2004-model-nigde/22330794', 'https://www.arabam.com/ilan/galeriden-satilik-chevrolet-cruze-1-6/galeriden-chevrolet-cruze-1-6-2010-model-nigde/22330650', 'https://www.arabam.com/ilan/galeriden-satilik-seat-altea-1-6-stylance/tr-nin-en-ucuzu-2005-model-katlanir-ayna-hiz-sabitleme/22540321', 'https://www.arabam.com/turbolar', 'https://www.arabam.com/ilan/sahibinden-satilik-honda-civic-1-6-i-vtec-dream/sahibinden-honda-civic-1-6-i-vtec-dream-2018-model/22580908', 'https://www.arabam.com/ilan/galeriden-satilik-volkswagen-passat-1-6-tdi-bluemotion-comfortline/tanriverdiler-otomotivden-hatasiz-degisensiz-tramersiz-rline/22581619', 'https://www.arabam.com/ilan/galeriden-satilik-jaguar-xe-2-0-d-prestige-plus/tarik-yildirim-otomotiv-hatasiz-boyasiz-jaguar-xe/22581523', 'https://www.arabam.com/ilan/galeriden-satilik-mercedes-benz-clk-230-kompressor/galeriden-mercedes-benz-clk-230-kompressor-1998-model-afyonkarahisar/22505180', 'https://www.arabam.com/ilan/galeriden-satilik-ford-focus-1-6-tdci-trend-x/hatasiz-tertemiz/22581445', 'https://www.arabam.com/ilan/galeriden-satilik-volkswagen-caddy-1-6-tdi-trendline/2013-caddy-trendline/22581399', 'https://www.arabam.com/ilan/galeriden-satilik-seat-leon-1-6-tdi-cr-style/galeriden-seat-leon-1-6-tdi-cr-style-2013-model-istanbul/22453967', 'https://www.arabam.com/ilan/galeriden-satilik-renault-megane-1-5-dci-touch/galeriden-renault-megane-1-5-dci-touch-2018-model-istanbul/22463477', 'https://www.arabam.com/ilan/galeriden-satilik-vo ...
# 41

# %%
# LINK LISTEMDEKI LINKLERE GIDECEK BIR YAPI INSAA ETMEK ISTIYORUM BU YUZDEN ONCE LINKLERI LISTEMDE KONTROL ETTIM
cardetail = []
for link in linklist:
    # GET METHODUYLA LISTEDEKI LINKLERE SELENIUMU GONDERDIM
    driver.get(link)
    
    #LINKLERIN TITTLELARINI YAZDIRDIM
    #print(driver.title)
    
    
    
    #HTML YAPISI ICINDE LI SPAN OLARAK BULUNAN !BENIM ASIL IHTIYACIM OLAN! DATALARI CEKECEK BIR FOR DONGUSU OLUSTURDUM
    for li in driver.find_elements(By.XPATH, '//*[@id="js-hook-for-observer-detail"]/div[2]'):
        #print(li.text)
        item = li.text
        cardetail.append(item)
        
# Close browser
#element = driver.find_element_by_xpath('//*[@id="js-hook-for-observer-detail"]/div[2]')
 #   print(element.text)

# %%
cardetail
# Out:
# ['1.459.500 TL\nTaşıt Kredini Hesapla\nMANİSA / ALAŞEHİR / TOYGAR MAHALLESİ\nİlan No:\n22581815\nİlan Tarihi:\n08 Mayıs 2023\nMarka:\nJeep\nSeri:\nGrand Cherokee\nModel:\n3.0 CRD Summit\nYıl:\n2013\nKilometre:\n277.000 km\nVites Tipi:\nOtomatik\nYakıt Tipi:\nDizel\nKasa Tipi:\nCrossover\nMotor Hacmi:\n2987 cc\nMotor Gücü:\n250 hp\nÇekiş:\n4WD (Sürekli)\nOrt. Yakıt Tüketimi:\n7,5 lt\nYakıt Deposu:\n93 lt\nBoya-değişen:\n2 değişen, 3 boyalı\nTakasa Uygun:\nTakasa Uygun Değil\nKimden:\nSahibinden\nKarşılaştır\nFavori\nPaylaş',
#  '794.500 TL\nTaşıt Kredini Hesapla\nDENİZLİ / PAMUKKALE / HACIKAPLANLAR MAHALLESİ\nİlan No:\n22581980\nİlan Tarihi:\n08 Mayıs 2023\nMarka:\nSeat\nSeri:\nLeon\nModel:\n1.4 TSI FR\nYıl:\n2016\nKilometre:\n220.000 km\nVites Tipi:\nYarı Otomatik\nYakıt Tipi:\nBenzin\nKasa Tipi:\nHatchback/5\nMotor Hacmi:\n1395 cc\nMotor Gücü:\n150 hp\nÇekiş:\nÖnden Çekiş\nOrt. Yakıt Tüketimi:\n5,6 lt\nYakıt Deposu:\n50 lt\nBoya-değişen:\nTamamı orjinal\nTakasa Uygun:\nTakasa Uygun\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '222.000 TL\nTaşıt Kredini Hesapla\nMANİSA / KULA / AKGÜN MAHALLESİ\nİlan No:\n22581944\nİlan Tarihi:\n08 Mayıs 2023\nMarka:\nFiat\nSeri:\nPalio\nModel:\n1.4 HL\nYıl:\n1998\nKilometre:\n222.000 km\nVites Tipi:\nDüz\nYakıt Tipi:\nLPG & Benzin\nKasa Tipi:\nHatchback/5\nMotor Hacmi:\n1368 cc\nMotor Gücü:\n77 hp\nÇekiş:\nÖnden Çekiş\nOrt. Yakıt Tüketimi:\n6,1 lt\nYakıt Deposu:\n51 lt\nBoya-değişen:\nTamamı boyalı\nTakasa Uygun:\nTakasa Uygun\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '1.235.000 TL\nTaşıt Kredini Hesapla\nİSTANBUL / BAŞAKŞEHİR / İKİTELLİ OSB\nİlan No:\n22581936\nİlan Tarihi:\n08 Mayıs 2023\nMarka:\nVolkswagen\nSeri:\nPassat\nModel:\n1.6 TDi BlueMotion Comfortline\nYıl:\n2018\nKilometre:\n82.000 km\nVites Tipi:\nYarı Otomatik\nYakıt Tipi:\nDizel\nKasa Tipi:\nSedan\nMotor Hacmi:\n1598 cc\nMotor Gücü:\n120 hp\nÇekiş:\nÖnden Çekiş\nOrt. Yakıt Tüketimi:\n4 lt\nYakıt Deposu:\n66 lt\nBoya-değişen:\nTamamı orjinal\nTakasa Uygun:\nTakasa Uygun Değil\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '1.580.000 TL\nTaşıt Kredini Hesapla\nISPARTA / MERKEZ / GÜLİSTAN MAHALLESİ\nİlan No:\n21588401\nİlan Tarihi:\n08 Mayıs 2023\nMarka:\nBMW\nSeri:\n3 Serisi\nModel:\n320i ED 40th Year Edition\nYıl:\n2016\nKilometre:\n126.000 km\nVites Tipi:\nOtomatik\nYakıt Tipi:\nBenzin\nKasa Tipi:\nSedan\nMotor Hacmi:\n1598 cc\nMotor Gücü:\n170 hp\nÇekiş:\nArkadan İtiş\nOrt. Yakıt Tüketimi:\n5,3 lt\nYakıt Deposu:\n60 lt\nBoya-değişen:\nBelirtilmemiş\nTakasa Uygun:\nTakasa Uygun\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '705.000 TL\nTaşıt Kredini Hesapla\nISPARTA / MERKEZ / GÜLİSTAN MAHALLESİ\nİlan No:\n22457858\nİlan Tarihi:\n08 Mayıs 2023\nMarka:\nVolkswagen\nSeri:\nPassat\nModel:\n1.4 TSi Comfortline\nYıl:\n2013\nKilometre:\n145.000 km\nVites Tipi:\nOtomatik\nYakıt Tipi:\nBenzin\nKasa Tipi:\nSedan\nMotor Hacmi:\n1390 cc\nMotor Gücü:\n122 hp\nÇekiş:\nÖnden Çekiş\nOrt. Yakıt Tüketimi:\n6,6 lt\nYakıt Deposu:\n70 lt\nBoya-değişen:\nBelirtilmemiş\nTakasa Uygun:\nTakasa Uygun\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '465.000 TL\nTaşıt Kredini Hesapla\nISPARTA / MERKEZ / GÜLİSTAN MAHALLESİ\nİlan No:\n22394222\nİlan Tarihi:\n08 Mayıs 2023\nMarka:\nFord\nSeri:\nFocus\nModel:\n1.6 TDCi Titanium\nYıl:\n2009\nKilometre:\n220.000 km\nVites Tipi:\nDüz\nYakıt Tipi:\nDizel\nKasa Tipi:\nSedan\nMotor Hacmi:\n1560 cc\nMotor Gücü:\n110 hp\nÇekiş:\nÖnden Çekiş\nOrt. Yakıt Tüketimi:\n4,5 lt\nYakıt Deposu:\n55 lt\nBoya-değişen:\nBelirtilmemiş\nTakasa Uygun:\nTakasa Uygun\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '585.000 TL\nTaşıt Kredini Hesapla\nANKARA / AKYURT / YILDIRIM MAHALLESİ\nİlan No:\n22537353\nİlan Tarihi:\n08 Mayıs 2023\nMarka:\nFord\nSeri:\nTourneo Courier\nModel:\n1.5 TDCi Delux\nYıl:\n2020\nKilometre:\n80.000 km\nVites Tipi:\nDüz\nYakıt Tipi:\nDizel\nKasa Tipi:\nCamlı Van\nMotor Hacmi:\n1499 cm3\nMotor Gücü:\n95 hp\nÇekiş:\n-\nKoltuk Sayısı:\n4+1\nAraç Cinsi (Ruhsat):\nKamyonet\nBoya-değişen:\nTamamı orjinal\nTakasa Uygun:\nTakasa Uygun Değil\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '245.000 TL\nTaşıt Kredini Hesapla\nVAN / EDREMİT / EMİNPAŞA MAHALLESİ\nİlan No:\n22531897\nİlan Tarihi:\n08 Mayıs 2023\nMarka:\nVolkswagen\nSeri:\nPassat\nModel:\n1.8 Trendline\nYıl:\n2000\nKilometre:\n292.000 km\nVites Tipi:\nDüz\nYakıt Tipi:\nLPG & Benzin\nKasa Tipi:\nSedan\nMotor Hacmi:\n1781 cc\nMotor Gücü:\n125 hp\nÇekiş:\n4WD (Sürekli)\nYakıt Deposu:\n62 lt\nBoya-değişen:\nBelirtilmemiş\nTakasa Uygun:\nTakasa Uygun Değil\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '345.000 TL\nTaşıt Kredini Hesapla\nAĞRI / MERKEZ / SITKIYE MAHALLESİ\nİlan No:\n22530211\nİlan Tarihi:\n08 Mayıs 2023\nMarka:\nFiat\nSeri:\nFiorino\nModel:\nFiorino Combi 1.3 Multijet Emotion\nYıl:\n2010\nKilometre:\n186.000 km\nVites Tipi:\nDüz\nYakıt Tipi:\nDizel\nKasa Tipi:\nCamlı Van\nMotor Hacmi:\n1248 cm3\nMotor Gücü:\n75 hp\nÇekiş:\n4x2 (Önden Çekişli)\nKoltuk Sayısı:\n4+1\nAraç Cinsi (Ruhsat):\nKamyonet\nBoya-değişen:\n1 boyalı\nTakasa Uygun:\nTakasa Uygun\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '444.444 TL\nTaşıt Kredini Hesapla\nERZURUM / YAKUTİYE / KAZIM KARABEKİR PAŞA MAHALLESİ\nİlan No:\n21731414\nİlan Tarihi:\n08 Mayıs 2023\nMarka:\nDAF\nSeri:\n105\nYıl:\n2017\nKilometre:\n675.000 km\nVites Tipi:\nOtomatik\nYakıt Tipi:\nDizel\nMotor Hacmi:\n11111 cm3\nMotor Gücü:\n460 hp\nKabin:\nNormal\nLastik Durumu (%):\n85 %\nRenk:\nBeyaz\nYatak:\n2\nDorse:\nYok\nTakasa Uygun:\nTakasa Uygun Değil\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '198.500 TL\nTaşıt Kredini Hesapla\nŞIRNAK / CİZRE / CUDİ MAHALLESİ\nİlan No:\n22581842\nİlan Tarihi:\n08 Mayıs 2023\nMarka:\nOpel\nSeri:\nVivaro\nModel:\n1.9 DTI\nYıl:\n2007\nKilometre:\n468.000 km\nVites Tipi:\nDüz\nYakıt Tipi:\nDizel\nKasa Tipi:\nCamlı Van\nMotor Hacmi:\n1870 cm3\nMotor Gücü:\n100 hp\nÇekiş:\n4x2 (Önden Çekişli)\nKoltuk Sayısı:\n9+1\nAraç Cinsi (Ruhsat):\nMinibüs\nBoya-değişen:\nBelirtilmemiş\nTakasa Uygun:\nTakasa Uygun Değil\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '539.500 TL\nTaşıt Kredini Hesapla\nANKARA / YENİMAHALLE / ERGAZİ MAHALLESİ\nİlan No:\n22581837\nİlan Tarihi:\n08 Mayıs 2023\nMarka:\nBMW\nSeri:\n3 Serisi\nModel:\n320d Premium\nYıl:\n2006\nKilometre:\n335.000 km\nVites Tipi:\nOtomatik\nYakıt Tipi:\nDizel\nKasa Tipi:\nSedan\nMotor Hacmi:\n1995 cc\nMotor Gücü:\n163 hp\nÇekiş:\nArkadan İtiş\nOrt. Yakıt Tüketimi:\n6,7 lt\nYakıt Deposu:\n60 lt\nBoya-değişen:\nBelirtilmemiş\nTakasa Uygun:\nTakasa Uygun Değil\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '470.000 TL\nTaşıt Kredini Hesapla\nTRABZON / VAKFIKEBİR / KEMALİYE MAHALLESİ\nİlan No:\n22428217\nİlan Tarihi:\n08 Mayıs 2023\nMarka:\nRenault\nSeri:\nMegane\nModel:\n1.5 dCi Touch\nYıl:\n2012\nKilometre:\n270.000 km\nVites Tipi:\nYarı Otomatik\nYakıt Tipi:\nDizel\nKasa Tipi:\nHatchback/5\nMotor Hacmi:\n1461 cc\nMotor Gücü:\n110 hp\nÇekiş:\nÖnden Çekiş\nOrt. Yakıt Tüketimi:\n4,4 lt\nYakıt Deposu:\n60 lt\nBoya-değişen:\nBelirtilmemiş\nTakasa Uygun:\nTakasa Uygun Değil\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '647.500 TL\nTaşıt Kredini Hesapla\nTRABZON / VAKFIKEBİR / KEMALİYE MAHALLESİ\nİlan No:\n22293988\nİlan Tarihi:\n08 Mayıs 2023\nMarka:\nDacia\nSeri:\nDuster\nModel:\n1.3 Tce Comfort\nYıl:\n2019\nKilometre:\n150.000 km\nVites Tipi:\nDüz\nYakıt Tipi:\nBenzin\nKasa Tipi:\nCrossover\nMotor Hacmi:\n1332 cc\nMotor Gücü:\n130 hp\nÇekiş:\nÖnden Çekiş\nOrt. Yakıt Tüketimi:\n5,8 lt\nYakıt Deposu:\n50 lt\nBoya-değişen:\n4 boyalı\nTakasa Uygun:\nTakasa Uygun Değil\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '400.000 TL\nTaşıt Kredini Hesapla\nANKARA / ALTINDAĞ / BEŞİKKAYA MAHALLESİ\nİlan No:\n22302909\nİlan Tarihi:\n08 Mayıs 2023\nMarka:\nBMW\nSeri:\n3 Serisi\nModel:\n320i\nYıl:\n2000\nKilometre:\n320.000 km\nVites Tipi:\nOtomatik\nYakıt Tipi:\nLPG & Benzin\nKasa Tipi:\nSedan\nMotor Hacmi:\n1991 cc\nMotor Gücü:\n170 hp\nÇekiş:\nArkadan İtiş\nOrt. Yakıt Tüketimi:\n9,4 lt\nYakıt Deposu:\n63 lt\nBoya-değişen:\n1 değişen, 10 boyalı\nTakasa Uygun:\nTakasa Uygun\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '879.900 TL\nTaşıt Kredini Hesapla\nAKSARAY / MERKEZ / HACILARHARMANI MAHALLESİ\nİlan No:\n22406234\nİlan Tarihi:\n08 Mayıs 2023\nMarka:\nVolkswagen\nSeri:\nGolf\nModel:\n1.6 TDi BlueMotion Comfortline\nYıl:\n2017\nKilometre:\n77.000 km\nVites Tipi:\nYarı Otomatik\nYakıt Tipi:\nDizel\nKasa Tipi:\nHatchback/5\nMotor Hacmi:\n1598 cc\nMotor Gücü:\n110 hp\nÇekiş:\nÖnden Çekiş\nOrt. Yakıt Tüketimi:\n3,9 lt\nYakıt Deposu:\n50 lt\nBoya-değişen:\n1 boyalı\nTakasa Uygun:\nTakasa Uygun Değil\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '344.500 TL\nTaşıt Kredini Hesapla\nNİĞDE / MERKEZ / ŞAHİNALİ MAHALLESİ\nİlan No:\n22330794\nİlan Tarihi:\n08 Mayıs 2023\nMarka:\nVolkswagen\nSeri:\nTransporter\nModel:\n2.5 TDI Camlı Van\nYıl:\n2004\nKilometre:\n340.000 km\nVites Tipi:\nDüz\nYakıt Tipi:\nDizel\nKasa Tipi:\nCamlı Van\nMotor Hacmi:\n2460 cm3\nMotor Gücü:\n130 hp\nÇekiş:\n4x2 (Önden Çekişli)\nKoltuk Sayısı:\n5+1\nAraç Cinsi (Ruhsat):\nKamyonet\nBoya-değişen:\nBelirtilmemiş\nTakasa Uygun:\nTakasa Uygun Değil\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '385.000 TL\nTaşıt Kredini Hesapla\nNİĞDE / MERKEZ / ŞAHİNALİ MAHALLESİ\nİlan No:\n22330650\nİlan Tarihi:\n08 Mayıs 2023\nMarka:\nChevrolet\nSeri:\nCruze\nModel:\n1.6\nYıl:\n2010\nKilometre:\n260.000 km\nVites Tipi:\nDüz\nYakıt Tipi:\nLPG & Benzin\nKasa Tipi:\nSedan\nMotor Hacmi:\n1598 cc\nMotor Gücü:\n124 hp\nÇekiş:\nÖnden Çekiş\nOrt. Yakıt Tüketimi:\n6,5 lt\nYakıt Deposu:\n60 lt\nBoya-değişen:\nBelirtilmemiş\nTakasa Uygun:\nTakasa Uygun Değil\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '243.900 TL\nTaşıt Kredini Hesapla\nANKARA / AKYURT / BALIKHİSAR MAHALLESİ\nİlan No:\n22540321\nİlan Tarihi:\n08 Mayıs 2023\nMarka:\nSeat\nSeri:\nAltea\nModel:\n1.6 Stylance\nYıl:\n2005\nKilometre:\n256.911 km\nVites Tipi:\nDüz\nYakıt Tipi:\nLPG & Benzin\nKasa Tipi:\nMPV\nMotor Hacmi:\n1595 cc\nMotor Gücü:\n102 hp\nÇekiş:\nÖnden Çekiş\nOrt. Yakıt Tüketimi:\n7,7 lt\nYakıt Deposu:\n55 lt\nBoya-değişen:\nBelirtilmemiş\nTakasa Uygun:\nTakasa Uygun\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '195.000 TL\nTaşıt Kredini Hesapla\nANTALYA / MANAVGAT / ILICA MAHALLESİ\nİlan No:\n22580908\nİlan Tarihi:\n08 Mayıs 2023\nMarka:\nHonda\nSeri:\nCivic\nModel:\n1.6 i-VTEC Dream\nYıl:\n2018\nKilometre:\n78.542 km\nVites Tipi:\nOtomatik\nYakıt Tipi:\nLPG & Benzin\nKasa Tipi:\nSedan\nMotor Hacmi:\n1598 cc\nMotor Gücü:\n125 hp\nÇekiş:\nÖnden Çekiş\nOrt. Yakıt Tüketimi:\n6,7 lt\nYakıt Deposu:\n50 lt\nBoya-değişen:\nTamamı orjinal\nTakasa Uygun:\nTakasa Uygun Değil\nKimden:\nSahibinden\nKarşılaştır\nFavori\nPaylaş',
#  '1.350.000 TL\nTaşıt Kredini Hesapla\nANKARA / GÖLBAŞI / KARŞIYAKA MAHALLESİ\nİlan No:\n22581619\nİlan Tarihi:\n08 Mayıs 2023\nMarka:\nVolkswagen\nSeri:\nPassat\nModel:\n1.6 TDi BlueMotion Comfortline\nYıl:\n2017\nKilometre:\n85.000 km\nVites Tipi:\nYarı Otomatik\nYakıt Tipi:\nDizel\nKasa Tipi:\nSedan\nMotor Hacmi:\n1598 cc\nMotor Gücü:\n120 hp\nÇekiş:\nÖnden Çekiş\nOrt. Yakıt Tüketimi:\n4 lt\nYakıt Deposu:\n66 lt\nBoya-değişen:\nBelirtilmemiş\nTakasa Uygun:\nTakasa Uygun\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '1.375.000 TL\nTaşıt Kredini Hesapla\nANTALYA / ALANYA / FIĞLA MAHALLESİ\nİlan No:\n22581523\nİlan Tarihi:\n08 Mayıs 2023\nMarka:\nJaguar\nSeri:\nXE\nModel:\n2.0 D Prestige Plus\nYıl:\n2015\nKilometre:\n175.890 km\nVites Tipi:\nOtomatik\nYakıt Tipi:\nDizel\nKasa Tipi:\nSedan\nMotor Hacmi:\n1999 cc\nMotor Gücü:\n180 hp\nÇekiş:\nArkadan İtiş\nOrt. Yakıt Tüketimi:\n4,2 lt\nYakıt Deposu:\n56 lt\nBoya-değişen:\nBelirtilmemiş\nTakasa Uygun:\nTakasa Uygun\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '575.000 TL\nTaşıt Kredini Hesapla\nAFYONKARAHİSAR / MERKEZ / YENİCE MAHALLESİ\nİlan No:\n22505180\nİlan Tarihi:\n08 Mayıs 2023\nMarka:\nMercedes - Benz\nSeri:\nCLK\nModel:\nCLK 230 Kompressor\nYıl:\n1998\nKilometre:\n305.000 km\nVites Tipi:\nDüz\nYakıt Tipi:\nBenzin\nKasa Tipi:\n-\nMotor Hacmi:\n2295 cc\nMotor Gücü:\n193 hp\nÇekiş:\nArkadan İtiş\nOrt. Yakıt Tüketimi:\n10,2 lt\nYakıt Deposu:\n70 lt\nBoya-değişen:\nTamamı boyalı\nTakasa Uygun:\nTakasa Uygun\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '564.750 TL\nTaşıt Kredini Hesapla\nANKARA / AKYURT / BALIKHİSAR MAHALLESİ\nİlan No:\n22581445\nİlan Tarihi:\n08 Mayıs 2023\nMarka:\nFord\nSeri:\nFocus\nModel:\n1.6 TDCi Trend X\nYıl:\n2015\nKilometre:\n195.000 km\nVites Tipi:\nDüz\nYakıt Tipi:\nDizel\nKasa Tipi:\nSedan\nMotor Hacmi:\n1560 cc\nMotor Gücü:\n95 hp\nÇekiş:\nÖnden Çekiş\nOrt. Yakıt Tüketimi:\n4,5 lt\nYakıt Deposu:\n53 lt\nBoya-değişen:\nBelirtilmemiş\nTakasa Uygun:\nTakasa Uygun\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '565.000 TL\nTaşıt Kredini Hesapla\nİSTANBUL / BAYRAMPAŞA / ORTAMAHALLE MAHALLESİ\nİlan No:\n22581399\nİlan Tarihi:\n08 Mayıs 2023\nMarka:\nVolkswagen\nSeri:\nCaddy\nModel:\n1.6 TDI Trendline\nYıl:\n2013\nKilometre:\n185.000 km\nVites Tipi:\nDüz\nYakıt Tipi:\nDizel\nKasa Tipi:\nCamlı Van\nMotor Hacmi:\n1598 cm3\nMotor Gücü:\n102 hp\nÇekiş:\n-\nKoltuk Sayısı:\n4+1\nAraç Cinsi (Ruhsat):\nKamyonet\nBoya-değişen:\n3 boyalı\nTakasa Uygun:\nTakasa Uygun\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '605.000 TL\nTaşıt Kredini Hesapla\nİSTANBUL / BAĞCILAR / 100. YIL MAHALLESİ\nİlan No:\n22453967\nİlan Tarihi:\n08 Mayıs 2023\nMarka:\nSeat\nSeri:\nLeon\nModel:\n1.6 TDI CR Style\nYıl:\n2013\nKilometre:\n264.000 km\nVites Tipi:\nYarı Otomatik\nYakıt Tipi:\nDizel\nKasa Tipi:\nHatchback/5\nMotor Hacmi:\n1598 cc\nMotor Gücü:\n105 hp\nÇekiş:\nÖnden Çekiş\nOrt. Yakıt Tüketimi:\n3,9 lt\nYakıt Deposu:\n50 lt\nBoya-değişen:\n6 boyalı\nTakasa Uygun:\nTakasa Uygun\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '715.000 TL\nTaşıt Kredini Hesapla\nİSTANBUL / BAĞCILAR / GÖZTEPE MAHALLESİ\nİlan No:\n22463477\nİlan Tarihi:\n08 Mayıs 2023\nMarka:\nRenault\nSeri:\nMegane\nModel:\n1.5 dCi Touch\nYıl:\n2018\nKilometre:\n147.000 km\nVites Tipi:\nYarı Otomatik\nYakıt Tipi:\nDizel\nKasa Tipi:\nHatchback/5\nMotor Hacmi:\n1461 cc\nMotor Gücü:\n110 hp\nÇekiş:\nÖnden Çekiş\nOrt. Yakıt Tüketimi:\n3,7 lt\nYakıt Deposu:\n47 lt\nBoya-değişen:\nBelirtilmemiş\nTakasa Uygun:\nTakasa Uygun Değil\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '645.000 TL\nTaşıt Kredini Hesapla\nİSTANBUL / BAĞCILAR / GÖZTEPE MAHALLESİ\nİlan No:\n22463466\nİlan Tarihi:\n08 Mayıs 2023\nMarka:\nVolkswagen\nSeri:\nPolo\nModel:\n1.4 TDi Comfortline\nYıl:\n2016\nKilometre:\n82.000 km\nVites Tipi:\nYarı Otomatik\nYakıt Tipi:\nDizel\nKasa Tipi:\nHatchback/5\nMotor Hacmi:\n1422 cc\nMotor Gücü:\n90 hp\nÇekiş:\nÖnden Çekiş\nOrt. Yakıt Tüketimi:\n3,5 lt\nYakıt Deposu:\n45 lt\nBoya-değişen:\nBelirtilmemiş\nTakasa Uygun:\nTakasa Uygun\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '605.000 TL\nTaşıt Kredini Hesapla\nİSTANBUL / BAĞCILAR / GÖZTEPE MAHALLESİ\nİlan No:\n22354643\nİlan Tarihi:\n08 Mayıs 2023\nMarka:\nFord\nSeri:\nTransit Custom\nModel:\n310 S Trend\nYıl:\n2016\nKilometre:\n184.200 km\nVites Tipi:\nDüz\nYakıt Tipi:\nDizel\nKasa Tipi:\nCamlı Van\nMotor Hacmi:\n2198 cm3\nMotor Gücü:\n125 hp\nÇekiş:\n4x2 (Önden Çekişli)\nKoltuk Sayısı:\n5+1\nAraç Cinsi (Ruhsat):\nKamyonet\nBoya-değişen:\n2 değişen, 3 boyalı\nTakasa Uygun:\nTakasa Uygun\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '1.290.000 TL\nTaşıt Kredini Hesapla\nANKARA / AKYURT / SARACALAR MAHALLESİ\nİlan No:\n21992926\nİlan Tarihi:\n08 Mayıs 2023\nMarka:\nFord\nSeri:\nMondeo\nModel:\n1.5 Titanium\nYıl:\n2020\nKilometre:\n108.000 km\nVites Tipi:\nOtomatik\nYakıt Tipi:\nBenzin\nKasa Tipi:\nStation wagon\nMotor Hacmi:\n1498 cc\nMotor Gücü:\n165 hp\nÇekiş:\nÖnden Çekiş\nOrt. Yakıt Tüketimi:\n6,5 lt\nYakıt Deposu:\n62 lt\nBoya-değişen:\nBelirtilmemiş\nTakasa Uygun:\nTakasa Uygun\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '2.350.000 TL\nTaşıt Kredini Hesapla\nİSTANBUL / BAĞCILAR / GÖZTEPE MAHALLESİ\nİlan No:\n22220831\nİlan Tarihi:\n08 Mayıs 2023\nMarka:\nVolvo\nSeri:\nS90\nModel:\n2.0 D5 Inscription\nYıl:\n2016\nKilometre:\n158.000 km\nVites Tipi:\nOtomatik\nYakıt Tipi:\nDizel\nKasa Tipi:\nSedan\nMotor Hacmi:\n1969 cc\nMotor Gücü:\n235 hp\nÇekiş:\n4WD (Sürekli)\nOrt. Yakıt Tüketimi:\n4,8 lt\nYakıt Deposu:\n60 lt\nBoya-değişen:\n2 değişen, 2 boyalı\nTakasa Uygun:\nTakasa Uygun Değil\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '1.300.000 TL\nTaşıt Kredini Hesapla\nİSTANBUL / KAĞITHANE / MERKEZ MAHALLESİ\nİlan No:\n22081459\nİlan Tarihi:\n08 Mayıs 2023\nMarka:\nJeep\nSeri:\nCompass\nModel:\n1.3 GSE Longitude\nYıl:\n2021\nKilometre:\n10.000 km\nVites Tipi:\nOtomatik\nYakıt Tipi:\nBenzin\nKasa Tipi:\nCrossover\nMotor Hacmi:\n1332 cc\nMotor Gücü:\n150 hp\nÇekiş:\nÖnden Çekiş\nOrt. Yakıt Tüketimi:\n5,6 lt\nYakıt Deposu:\n55 lt\nBoya-değişen:\nTamamı orjinal\nTakasa Uygun:\nTakasa Uygun Değil\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '905.000 TL\nTaşıt Kredini Hesapla\nİSTANBUL / BAYRAMPAŞA / ORTAMAHALLE MAHALLESİ\nİlan No:\n22581130\nİlan Tarihi:\n08 Mayıs 2023\nMarka:\nAudi\nSeri:\nA3\nModel:\nA3 Sportback 1.0 TFSI Dynamic\nYıl:\n2017\nKilometre:\n208.000 km\nVites Tipi:\nYarı Otomatik\nYakıt Tipi:\nBenzin\nKasa Tipi:\nHatchback/5\nMotor Hacmi:\n999 cc\nMotor Gücü:\n116 hp\nÇekiş:\nÖnden Çekiş\nOrt. Yakıt Tüketimi:\n4,5 lt\nYakıt Deposu:\n50 lt\nBoya-değişen:\n1 değişen, 2 boyalı\nTakasa Uygun:\n-\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '320.000 TL\nTaşıt Kredini Hesapla\nANKARA / SİNCAN / AKŞEMSETTİN MAHALLESİ\nİlan No:\n22314304\nİlan Tarihi:\n08 Mayıs 2023\nMarka:\nFiat\nSeri:\nFiorino\nModel:\nFiorino Combi 1.3 Multijet Pop\nYıl:\n2017\nKilometre:\n187.000 km\nVites Tipi:\nDüz\nYakıt Tipi:\nDizel\nKasa Tipi:\nCamlı Van\nMotor Hacmi:\n1248 cm3\nMotor Gücü:\n75 hp\nÇekiş:\n4x2 (Önden Çekişli)\nKoltuk Sayısı:\n4+1\nAraç Cinsi (Ruhsat):\nKamyonet\nBoya-değişen:\n1 değişen, 1 boyalı\nTakasa Uygun:\nTakasa Uygun\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '280.000 TL\nTaşıt Kredini Hesapla\nİSTANBUL / AVCILAR / MERKEZ MAHALLESİ\nİlan No:\n21708677\nİlan Tarihi:\n08 Mayıs 2023\nMarka:\nFiat\nSeri:\nFiorino\nModel:\nFiorino Combi 1.3 Multijet Dynamic\nYıl:\n2011\nKilometre:\n275.000 km\nVites Tipi:\nDüz\nYakıt Tipi:\nDizel\nKasa Tipi:\nYarım Camlı Van\nMotor Hacmi:\n1248 cm3\nMotor Gücü:\n75 hp\nÇekiş:\n-\nKoltuk Sayısı:\n4+1\nAraç Cinsi (Ruhsat):\nKamyonet\nBoya-değişen:\nBelirtilmemiş\nTakasa Uygun:\nTakasa Uygun\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '568.000 TL\nTaşıt Kredini Hesapla\nANKARA / AKYURT / SARACALAR MAHALLESİ\nİlan No:\n22581137\nİlan Tarihi:\n08 Mayıs 2023\nMarka:\nChevrolet\nSeri:\nCaptiva\nModel:\n2.0 D LT High\nYıl:\n2011\nKilometre:\n255.000 km\nVites Tipi:\nOtomatik\nYakıt Tipi:\nDizel\nKasa Tipi:\nCrossover\nMotor Hacmi:\n1991 cc\nMotor Gücü:\n150 hp\nÇekiş:\n4WD (Sürekli)\nOrt. Yakıt Tüketimi:\n8,7 lt\nYakıt Deposu:\n65 lt\nBoya-değişen:\n2 boyalı\nTakasa Uygun:\nTakasa Uygun\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '430.000 TL\nTaşıt Kredini Hesapla\nNİĞDE / MERKEZ / İLHANLI MAHALLESİ\nİlan No:\n22562721\nİlan Tarihi:\n08 Mayıs 2023\nMarka:\nAudi\nSeri:\nA4\nModel:\nA4 Sedan 1.6\nYıl:\n2004\nKilometre:\n200.000 km\nVites Tipi:\nDüz\nYakıt Tipi:\nLPG & Benzin\nKasa Tipi:\nSedan\nMotor Hacmi:\n1595 cc\nMotor Gücü:\n102 hp\nÇekiş:\nÖnden Çekiş\nOrt. Yakıt Tüketimi:\n8 lt\nYakıt Deposu:\n70 lt\nBoya-değişen:\nBelirtilmemiş\nTakasa Uygun:\nTakasa Uygun\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '187.000 TL\nTaşıt Kredini Hesapla\nAFYONKARAHİSAR / MERKEZ / FATİH MAHALLESİ\nİlan No:\n22543058\nİlan Tarihi:\n08 Mayıs 2023\nMarka:\nPeugeot\nSeri:\n206\nModel:\n1.4 HDi X-line\nYıl:\n2003\nKilometre:\n197.000 km\nVites Tipi:\nDüz\nYakıt Tipi:\nDizel\nKasa Tipi:\nHatchback/5\nMotor Hacmi:\n1398 cc\nMotor Gücü:\n69 hp\nÇekiş:\nÖnden Çekiş\nOrt. Yakıt Tüketimi:\n4,3 lt\nYakıt Deposu:\n50 lt\nBoya-değişen:\nBelirtilmemiş\nTakasa Uygun:\nTakasa Uygun\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş',
#  '120.000 TL\nTaşıt Kredini Hesapla\nAFYONKARAHİSAR / MERKEZ / FATİH MAHALLESİ\nİlan No:\n22375061\nİlan Tarihi:\n08 Mayıs 2023\nMarka:\nFiat\nSeri:\nUno\nModel:\n70 S\nYıl:\n1999\nKilometre:\n300.000 km\nVites Tipi:\nDüz\nYakıt Tipi:\nLPG & Benzin\nKasa Tipi:\nHatchback/5\nMotor Hacmi:\n1372 cc\nMotor Gücü:\n71 hp\nÇekiş:\nÖnden Çekiş\nYakıt Deposu:\n42 lt\nBoya-değişen:\nBelirtilmemiş\nTakasa Uygun:\nTakasa Uygun\nKimden:\nGaleriden\nKarşılaştır\nFavori\nPaylaş']

# %%
cardetail[0]
# Out:
# '1.459.500 TL\nTaşıt Kredini Hesapla\nMANİSA / ALAŞEHİR / TOYGAR MAHALLESİ\nİlan No:\n22581815\nİlan Tarihi:\n08 Mayıs 2023\nMarka:\nJeep\nSeri:\nGrand Cherokee\nModel:\n3.0 CRD Summit\nYıl:\n2013\nKilometre:\n277.000 km\nVites Tipi:\nOtomatik\nYakıt Tipi:\nDizel\nKasa Tipi:\nCrossover\nMotor Hacmi:\n2987 cc\nMotor Gücü:\n250 hp\nÇekiş:\n4WD (Sürekli)\nOrt. Yakıt Tüketimi:\n7,5 lt\nYakıt Deposu:\n93 lt\nBoya-değişen:\n2 değişen, 3 boyalı\nTakasa Uygun:\nTakasa Uygun Değil\nKimden:\nSahibinden\nKarşılaştır\nFavori\nPaylaş'

# %%
type(cardetail)
# Out:
# list

# %%
new_data = []

for item in cardetail:
    # Satırları ayırarak bir liste oluşturdum
    item_list = item.split('\n')
    # Boş olan elemanları listeden çıkardım
    item_list = list(filter(None, item_list))
    # İlan tarihi ve marka değerlerini yeni bir liste olarak ekledim
    new_item = []
    for i in range(0, len(item_list), 2):
        new_item.append(item_list[i])
    # Yeni oluşan listeyi ana listede sakladım
    new_data.append(new_item)
    
# Yeni oluşan liste
print(new_data)
# Out:
# [['1.459.500 TL', 'MANİSA / ALAŞEHİR / TOYGAR MAHALLESİ', '22581815', '08 Mayıs 2023', 'Jeep', 'Grand Cherokee', '3.0 CRD Summit', '2013', '277.000 km', 'Otomatik', 'Dizel', 'Crossover', '2987 cc', '250 hp', '4WD (Sürekli)', '7,5 lt', '93 lt', '2 değişen, 3 boyalı', 'Takasa Uygun Değil', 'Sahibinden', 'Favori'], ['794.500 TL', 'DENİZLİ / PAMUKKALE / HACIKAPLANLAR MAHALLESİ', '22581980', '08 Mayıs 2023', 'Seat', 'Leon', '1.4 TSI FR', '2016', '220.000 km', 'Yarı Otomatik', 'Benzin', 'Hatchback/5', '1395 cc', '150 hp', 'Önden Çekiş', '5,6 lt', '50 lt', 'Tamamı orjinal', 'Takasa Uygun', 'Galeriden', 'Favori'], ['222.000 TL', 'MANİSA / KULA / AKGÜN MAHALLESİ', '22581944', '08 Mayıs 2023', 'Fiat', 'Palio', '1.4 HL', '1998', '222.000 km', 'Düz', 'LPG & Benzin', 'Hatchback/5', '1368 cc', '77 hp', 'Önden Çekiş', '6,1 lt', '51 lt', 'Tamamı boyalı', 'Takasa Uygun', 'Galeriden', 'Favori'], ['1.235.000 TL', 'İSTANBUL / BAŞAKŞEHİR / İKİTELLİ OSB', '22581936', '08 Mayıs 2023', 'Volkswagen', 'Passat', '1.6 TDi BlueMotion Comfortline', '2018', '82.000 km', 'Yarı Otomatik', 'Dizel', 'Sedan', '1598 cc', '120 hp', 'Önden Çekiş', '4 lt', '66 lt', 'Tamamı orjinal', 'Takasa Uygun Değil', 'Galeriden', 'Favori'], ['1.580.000 TL', 'ISPARTA / MERKEZ / GÜLİSTAN MAHALLESİ', '21588401', '08 Mayıs 2023', 'BMW', '3 Serisi', '320i ED 40th Year Edition', '2016', '126.000 km', 'Otomatik', 'Benzin', 'Sedan', '1598 cc', '170 hp', 'Arkadan İtiş', '5,3 lt', '60 lt', 'Belirtilmemiş', 'Takasa Uygun', 'Galeriden', 'Favori'], ['705.000 TL', 'ISPARTA / MERKEZ / GÜLİSTAN MAHALLESİ', '22457858', '08 Mayıs 2023', 'Volkswagen', 'Passat', '1.4 TSi Comfortline', '2013', '145.000 km', 'Otomatik', 'Benzin', 'Sedan', '1390 cc', '122 hp', 'Önden Çekiş', '6,6 lt', '70 lt', 'Belirtilmemiş', 'Takasa Uygun', 'Galeriden', 'Favori'], ['465.000 TL', 'ISPARTA / MERKEZ / GÜLİSTAN MAHALLESİ', '22394222', '08 Mayıs 2023', 'Ford', 'Focus', '1.6 TDCi Titanium', '2009', '220.000 km', 'Düz', 'Dizel', 'Sedan', '1560 cc', '110 hp', 'Önden Çekiş', '4,5 lt', '55 lt', 'Belirtilmemiş', 'Takasa Uygun', 'Galeriden', 'Favori'], ['585.000 TL', 'ANKARA / AKYURT / YILDIRIM MAHALLESİ', '22537353', '08 Mayıs 2023', 'Ford', 'Tourneo Courier', '1.5 TDCi Delux', '2020', '80.000 km', 'Düz', 'Dizel', 'Camlı Van', '1499 cm3', '95 hp', '-', '4+1', 'Kamyonet', 'Tamamı orjinal', 'Takasa Uygun Değil', 'Galeriden', 'Favori'], ['245.000 TL', 'VAN / EDREMİT / EMİNPAŞA MAHALLESİ', '22531897', '08 Mayıs 2023', 'Volkswagen', 'Passat', '1.8 Trendline', '2000', '292.000 km', 'Düz', 'LPG & Benzin', 'Sedan', '1781 cc', '125 hp', '4WD (Sürekli)', '62 lt', 'Belirtilmemiş', 'Takasa Uygun Değil', 'Galeriden', 'Favori'], ['345.000 TL', 'AĞRI / MERKEZ / SITKIYE MAHALLESİ', '22530211', '08 Mayıs 2023', 'Fiat', 'Fiorino', 'Fiorino Combi 1.3 Multijet Emotion', '2010', '186.000 km', 'Düz', 'Dizel', 'Camlı Van', '1248 cm3', '75 hp', '4x2 (Önden Çekişli)', '4+1', 'Kamyonet', '1 boyalı', 'Takasa Uygun', 'Galeriden', 'Favori'], ['444.444 TL', 'ERZURUM / YAKUTİYE / KAZIM KARABEKİR PAŞA MAHALLESİ', '21731414', '08 Mayıs 2023', 'DAF', '105', '2017', '675.000 km', 'Otomatik', 'Dizel', '11111 cm3', '460 hp', 'Normal', '85 %', 'Beyaz', '2', 'Yok', 'Takasa Uygun Değil', 'Galeriden', 'Favori'], ['198.500 TL', 'ŞIRNAK / CİZRE / CUDİ MAHALLESİ', '22581842', '08 Mayıs 2023', 'Opel', 'Vivaro', '1.9 DTI', '2007', '468.000 km', 'Düz', 'Dizel', 'Camlı Van', '1870 cm3', '100 hp', '4x2 (Önden Çekişli)', '9+1', 'Minibüs', 'Belirtilmemiş', 'Takasa Uygun Değil', 'Galeriden', 'Favori'], ['539.500 TL', 'ANKARA / YENİMAHALLE / ERGAZİ MAHALLESİ', '22581837', '08 Mayıs 2023', 'BMW', '3 Serisi', '320d Premium', '2006', '335.000 km', 'Otomatik', 'Dizel', 'Sedan', '1995 cc', '163 hp', 'Arkadan İtiş', '6,7 lt', '60 lt', 'Belirtilmemiş', 'Takasa Uygun Değil', 'Galeriden', 'Favori'], ['470.000 TL', 'TRABZON / VAKFIKEBİR / KEMALİYE MAHALLESİ', '22428217', '08 Mayıs 2023', 'Renault', 'Megane', '1.5 dCi Touch', '2012', '270.000 km', 'Yarı Otomatik', 'Dizel', 'Hatchback/5', ' ...

# %%
new_data[0]
# Out:
# ['1.459.500 TL',
#  'MANİSA / ALAŞEHİR / TOYGAR MAHALLESİ',
#  '22581815',
#  '08 Mayıs 2023',
#  'Jeep',
#  'Grand Cherokee',
#  '3.0 CRD Summit',
#  '2013',
#  '277.000 km',
#  'Otomatik',
#  'Dizel',
#  'Crossover',
#  '2987 cc',
#  '250 hp',
#  '4WD (Sürekli)',
#  '7,5 lt',
#  '93 lt',
#  '2 değişen, 3 boyalı',
#  'Takasa Uygun Değil',
#  'Sahibinden',
#  'Favori']

# %%
new_data[0][0]
# Out:
# '1.459.500 TL'

# %%
for data in new_data:
    data[0] = data[0].replace(' TL', '')
    data[8] = data[8].replace(' km', '')
new_data    
    #listedeki bütün fiyatların sonundaki TL stringini kaldırmaya çalışıyorum**
# Out:
# [['1.459.500',
#   'MANİSA / ALAŞEHİR / TOYGAR MAHALLESİ',
#   '22581815',
#   '08 Mayıs 2023',
#   'Jeep',
#   'Grand Cherokee',
#   '3.0 CRD Summit',
#   '2013',
#   '277.000',
#   'Otomatik',
#   'Dizel',
#   'Crossover',
#   '2987 cc',
#   '250 hp',
#   '4WD (Sürekli)',
#   '7,5 lt',
#   '93 lt',
#   '2 değişen, 3 boyalı',
#   'Takasa Uygun Değil',
#   'Sahibinden',
#   'Favori'],
#  ['794.500',
#   'DENİZLİ / PAMUKKALE / HACIKAPLANLAR MAHALLESİ',
#   '22581980',
#   '08 Mayıs 2023',
#   'Seat',
#   'Leon',
#   '1.4 TSI FR',
#   '2016',
#   '220.000',
#   'Yarı Otomatik',
#   'Benzin',
#   'Hatchback/5',
#   '1395 cc',
#   '150 hp',
#   'Önden Çekiş',
#   '5,6 lt',
#   '50 lt',
#   'Tamamı orjinal',
#   'Takasa Uygun',
#   'Galeriden',
#   'Favori'],
#  ['222.000',
#   'MANİSA / KULA / AKGÜN MAHALLESİ',
#   '22581944',
#   '08 Mayıs 2023',
#   'Fiat',
#   'Palio',
#   '1.4 HL',
#   '1998',
#   '222.000',
#   'Düz',
#   'LPG & Benzin',
#   'Hatchback/5',
#   '1368 cc',
#   '77 hp',
#   'Önden Çekiş',
#   '6,1 lt',
#   '51 lt',
#   'Tamamı boyalı',
#   'Takasa Uygun',
#   'Galeriden',
#   'Favori'],
#  ['1.235.000',
#   'İSTANBUL / BAŞAKŞEHİR / İKİTELLİ OSB',
#   '22581936',
#   '08 Mayıs 2023',
#   'Volkswagen',
#   'Passat',
#   '1.6 TDi BlueMotion Comfortline',
#   '2018',
#   '82.000',
#   'Yarı Otomatik',
#   'Dizel',
#   'Sedan',
#   '1598 cc',
#   '120 hp',
#   'Önden Çekiş',
#   '4 lt',
#   '66 lt',
#   'Tamamı orjinal',
#   'Takasa Uygun Değil',
#   'Galeriden',
#   'Favori'],
#  ['1.580.000',
#   'ISPARTA / MERKEZ / GÜLİSTAN MAHALLESİ',
#   '21588401',
#   '08 Mayıs 2023',
#   'BMW',
#   '3 Serisi',
#   '320i ED 40th Year Edition',
#   '2016',
#   '126.000',
#   'Otomatik',
#   'Benzin',
#   'Sedan',
#   '1598 cc',
#   '170 hp',
#   'Arkadan İtiş',
#   '5,3 lt',
#   '60 lt',
#   'Belirtilmemiş',
#   'Takasa Uygun',
#   'Galeriden',
#   'Favori'],
#  ['705.000',
#   'ISPARTA / MERKEZ / GÜLİSTAN MAHALLESİ',
#   '22457858',
#   '08 Mayıs 2023',
#   'Volkswagen',
#   'Passat',
#   '1.4 TSi Comfortline',
#   '2013',
#   '145.000',
#   'Otomatik',
#   'Benzin',
#   'Sedan',
#   '1390 cc',
#   '122 hp',
#   'Önden Çekiş',
#   '6,6 lt',
#   '70 lt',
#   'Belirtilmemiş',
#   'Takasa Uygun',
#   'Galeriden',
#   'Favori'],
#  ['465.000',
#   'ISPARTA / MERKEZ / GÜLİSTAN MAHALLESİ',
#   '22394222',
#   '08 Mayıs 2023',
#   'Ford',
#   'Focus',
#   '1.6 TDCi Titanium',
#   '2009',
#   '220.000',
#   'Düz',
#   'Dizel',
#   'Sedan',
#   '1560 cc',
#   '110 hp',
#   'Önden Çekiş',
#   '4,5 lt',
#   '55 lt',
#   'Belirtilmemiş',
#   'Takasa Uygun',
#   'Galeriden',
#   'Favori'],
#  ['585.000',
#   'ANKARA / AKYURT / YILDIRIM MAHALLESİ',
#   '22537353',
#   '08 Mayıs 2023',
#   'Ford',
#   'Tourneo Courier',
#   '1.5 TDCi Delux',
#   '2020',
#   '80.000',
#   'Düz',
#   'Dizel',
#   'Camlı Van',
#   '1499 cm3',
#   '95 hp',
#   '-',
#   '4+1',
#   'Kamyonet',
#   'Tamamı orjinal',
#   'Takasa Uygun Değil',
#   'Galeriden',
#   'Favori'],
#  ['245.000',
#   'VAN / EDREMİT / EMİNPAŞA MAHALLESİ',
#   '22531897',
#   '08 Mayıs 2023',
#   'Volkswagen',
#   'Passat',
#   '1.8 Trendline',
#   '2000',
#   '292.000',
#   'Düz',
#   'LPG & Benzin',
#   'Sedan',
#   '1781 cc',
#   '125 hp',
#   '4WD (Sürekli)',
#   '62 lt',
#   'Belirtilmemiş',
#   'Takasa Uygun Değil',
#   'Galeriden',
#   'Favori'],
#  ['345.000',
#   'AĞRI / MERKEZ / SITKIYE MAHALLESİ',
#   '22530211',
#   '08 Mayıs 2023',
#   'Fiat',
#   'Fiorino',
#   'Fiorino Combi 1.3 Multijet Emotion',
#   '2010',
#   '186.000',
#   'Düz',
#   'Dizel',
#   'Camlı Van',
#   '1248 cm3',
#   '75 hp',
#   '4x2 (Önden Çekişli)',
#   '4+1',
#   'Kamyonet',
#   '1 boyalı',
#   'Takasa Uygun',
#   'Galeriden',
#   'Favori'],
#  ['444.444',
#   'ERZURUM / YAKUTİYE / KAZIM KARABEKİR PAŞA MAHALLESİ',
#   '21731414',
#   '08 Mayıs 2023',
#   'DAF',
#   '105',
#   '2017',
#   '675.000 km',
#   'Otomatik',
#   'Dizel',
#   '11111 cm3',
#   '460 hp',
#   'Normal',
#   '85 %',
#   'Beyaz',
#   '2',
#   'Yok',
#   'Takasa Uygun Değil',
#   'Galeriden',
#   'Favori'],
#  ['198.500',
#   'ŞIRNAK / CİZRE / CUDİ MAHALLESİ',
#   '22581842',
#   '08 Mayıs 2023',
#   'Opel',
#   'Vivaro',
#   '1.9 DTI',
#   '2007',
#   '468.000',
#   'Düz',
#   'Dizel',
#   'Camlı Van',
#   '1870 cm3',
#   '100 hp',
#   '4x2 (Önden Çekişli)',
#   '9+1',
#   'Minibüs',
#   'Belirtilmemiş',
#   'Takasa Uygun Değil',
#   'Galeriden',
#   'Favori'],
#  ['539.500',
#   'ANKARA / YENİMAHALLE / ERGAZİ MAHALLESİ',
#   '22581837',
#   '08 Mayıs 2023',
#   'BMW',
#   '3 Serisi',
#   '320d Premium',
#   '2006',
#   '335.000',
#   'Otomatik',
#   'Dizel',
#   'Sedan',
#   '1995 cc',
#   '163 hp',
#   'Arkadan İtiş',
#   '6,7 lt',
#   '60 lt',
#   'Belirtilmemiş',
#   'Takasa Uygun Değil',
#   'Galeriden',
#   'Favori'],
#  ['470.000',
#   'TRABZON / VAKFIKEBİR / KEMALİYE MAHALLESİ',
#   '22428217',
#   '08 Mayıs 2023',
#   'Renault',
#   'Megane',
#   '1.5 dCi Touch',
#   '2012',
#   '270.000',
#   'Yarı Otomatik',
#   'Dizel',
#   'Hatchback/5',
#   '1461 cc',
#   '110 hp',
#   'Önden Çekiş',
#   '4,4 lt',
#   '60 lt',
#   'Belirtilmemiş',
#   'Takasa Uygun Değil',
#   'Galeriden',
#   'Favori'],
#  ['647.500',
#   'TRABZON / VAKFIKEBİR / KEMALİYE MAHALLESİ',
#   '22293988',
#   '08 Mayıs 2023',
#   'Dacia',
#   'Duster',
#   '1.3 Tce Comfort',
#   '2019',
#   '150.000',
#   'Düz',
#   'Benzin',
#   'Crossover',
#   '1332 cc',
#   '130 hp',
#   'Önden Çekiş',
#   '5,8 lt',
#   '50 lt',
#   '4 boyalı',
#   'Takasa Uygun Değil',
#   'Galeriden',
#   'Favori'],
#  ['400.000',
#   'ANKARA / ALTINDAĞ / BEŞİKKAYA MAHALLESİ',
#   '22302909',
#   '08 Mayıs 2023',
#   'BMW',
#   '3 Serisi',
#   '320i',
#   '2000',
#   '320.000',
#   'Otomatik',
#   'LPG & Benzin',
#   'Sedan',
#   '1991 cc',
#   '170 hp',
#   'Arkadan İtiş',
#   '9,4 lt',
#   '63 lt',
#   '1 değişen, 10 boyalı',
#   'Takasa Uygun',
#   'Galeriden',
#   'Favori'],
#  ['879.900',
#   'AKSARAY / MERKEZ / HACILARHARMANI MAHALLESİ',
#   '22406234',
#   '08 Mayıs 2023',
#   'Volkswagen',
#   'Golf',
#   '1.6 TDi BlueMotion Comfortline',
#   '2017',
#   '77.000',
#   'Yarı Otomatik',
#   'Dizel',
#   'Hatchback/5',
#   '1598 cc',
#   '110 hp',
#   'Önden Çekiş',
#   '3,9 lt',
#   '50 lt',
#   '1 boyalı',
#   'Takasa Uygun Değil',
#   'Galeriden',
#   'Favori'],
#  ['344.500',
#   'NİĞDE / MERKEZ / ŞAHİNALİ MAHALLESİ',
#   '22330794',
#   '08 Mayıs 2023',
#   'Volkswagen',
#   'Transporter',
#   '2.5 TDI Camlı Van',
#   '2004',
#   '340.000',
#   'Düz',
#   'Dizel',
#   'Camlı Van',
#   '2460 cm3',
#   '130 hp',
#   '4x2 (Önden Çekişli)',
#   '5+1',
#   'Kamyonet',
#   'Belirtilmemiş',
#   'Takasa Uygun Değil',
#   'Galeriden',
#   'Favori'],
#  ['385.000',
#   'NİĞDE / MERKEZ / ŞAHİNALİ MAHALLESİ',
#   '22330650',
#   '08 Mayıs 2023',
#   'Chevrolet',
#   'Cruze',
#   '1.6',
#   '2010',
#   '260.000',
#   'Düz',
#   'LPG & Benzin',
#   'Sedan',
#   '1598 cc',
#   '124 hp',
#   'Önden Çekiş',
#   '6,5 lt',
#   '60 lt',
#   'Belirtilmemiş',
#   'Takasa Uygun Değil',
#   'Galeriden',
#   'Favori'],
#  ['243.900',
#   'ANKARA / AKYURT / BALIKHİSAR MAHALLESİ',
#   '22540321',
#   '08 Mayıs 2023',
#   'Seat',
#   'Altea',
#   '1.6 Stylance',
#   '2005',
#   '256.911',
#   'Düz',
#   'LPG & Benzin',
#   'MPV',
#   '1595 cc',
#   '102 hp',
#   'Önden Çekiş',
#   '7,7 lt',
#   '55 lt',
#   'Belirtilmemiş',
#   'Takasa Uygun',
#   'Galeriden',
#   'Favori'],
#  ['195.000',
#   'ANTALYA / MANAVGAT / ILICA MAHALLESİ',
#   '22580908',
#   '08 Mayıs 2023',
#   'Honda',
#   'Civic',
#   '1.6 i-VTEC Dream',
#   '2018',
#   '78.542',
#   'Otomatik',
#   'LPG & Benzin',
#   'Sedan',
#   '1598 cc',
#   '125 hp',
#   'Önden Çekiş',
#   '6,7 lt',
#   '50 lt',
#   'Tamamı orjinal',
#   'Takasa Uygun Değil',
#   'Sahibinden',
#   'Favori'],
#  ['1.350.000',
#   'ANKARA / GÖLBAŞI / KARŞIYAKA MAHALLESİ',
#   '22581619',
#   '08 Mayıs 2023',
#   'Volkswagen',
#   'Passat',
#   '1.6 TDi BlueMotion Comfortline',
#   '2017',
#   '85.000',
#   'Yarı Otomatik',
#   'Dizel',
#   'Sedan',
#   '1598 cc',
#   '120 hp',
#   'Önden Çekiş',
#   '4 lt',
#   '66 lt',
#   'Belirtilmemiş',
#   'Takasa Uygun',
#   'Galeriden',
#   'Favori'],
#  ['1.375.000',
#   'ANTALYA / ALANYA / FIĞLA MAHALLESİ',
#   '22581523',
#   '08 Mayıs 2023',
#   'Jaguar',
#   'XE',
#   '2.0 D Prestige Plus',
#   '2015',
#   '175.890',
#   'Otomatik',
#   'Dizel',
#   'Sedan',
#   '1999 cc',
#   '180 hp',
#   'Arkadan İtiş',
#   '4,2 lt',
#   '56 lt',
#   'Belirtilmemiş',
#   'Takasa Uygun',
#   'Galeriden',
#   'Favori'],
#  ['575.000',
#   'AFYONKARAHİSAR / MERKEZ / YENİCE MAHALLESİ',
#   '22505180',
#   '08 Mayıs 2023',
#   'Mercedes - Benz',
#   'CLK',
#   'CLK 230 Kompressor',
#   '1998',
#   '305.000',
#   'Düz',
#   'Benzin',
#   '-',
#   '2295 cc',
#   '193 hp',
#   'Arkadan İtiş',
#   '10,2 lt',
#   '70 lt',
#   'Tamamı boyalı',
#   'Takasa Uygun',
#   'Galeriden',
#   'Favori'],
#  ['564.750',
#   'ANKARA / AKYURT / BALIKHİSAR MAHALLESİ',
#   '22581445',
#   '08 Mayıs 2023',
#   'Ford',
#   'Focus',
#   '1.6 TDCi Trend X',
#   '2015',
#   '195.000',
#   'Düz',
#   'Dizel',
#   'Sedan',
#   '1560 cc',
#   '95 hp',
#   'Önden Çekiş',
#   '4,5 lt',
#   '53 lt',
#   'Belirtilmemiş',
#   'Takasa Uygun',
#   'Galeriden',
#   'Favori'],
#  ['565.000',
#   'İSTANBUL / BAYRAMPAŞA / ORTAMAHALLE MAHALLESİ',
#   '22581399',
#   '08 Mayıs 2023',
#   'Volkswagen',
#   'Caddy',
#   '1.6 TDI Trendline',
#   '2013',
#   '185.000',
#   'Düz',
#   'Dizel',
#   'Camlı Van',
#   '1598 cm3',
#   '102 hp',
#   '-',
#   '4+1',
#   'Kamyonet',
#   '3 boyalı',
#   'Takasa Uygun',
#   'Galeriden',
#   'Favori'],
#  ['605.000',
#   'İSTANBUL / BAĞCILAR / 100. YIL MAHALLESİ',
#   '22453967',
#   '08 Mayıs 2023',
#   'Seat',
#   'Leon',
#   '1.6 TDI CR Style',
#   '2013',
#   '264.000',
#   'Yarı Otomatik',
#   'Dizel',
#   'Hatchback/5',
#   '1598 cc',
#   '105 hp',
#   'Önden Çekiş',
#   '3,9 lt',
#   '50 lt',
#   '6 boyalı',
#   'Takasa Uygun',
#   'Galeriden',
#   'Favori'],
#  ['715.000',
#   'İSTANBUL / BAĞCILAR / GÖZTEPE MAHALLESİ',
#   '22463477',
#   '08 Mayıs 2023',
#   'Renault',
#   'Megane',
#   '1.5 dCi Touch',
#   '2018',
#   '147.000',
#   'Yarı Otomatik',
#   'Dizel',
#   'Hatchback/5',
#   '1461 cc',
#   '110 hp',
#   'Önden Çekiş',
#   '3,7 lt',
#   '47 lt',
#   'Belirtilmemiş',
#   'Takasa Uygun Değil',
#   'Galeriden',
#   'Favori'],
#  ['645.000',
#   'İSTANBUL / BAĞCILAR / GÖZTEPE MAHALLESİ',
#   '22463466',
#   '08 Mayıs 2023',
#   'Volkswagen',
#   'Polo',
#   '1.4 TDi Comfortline',
#   '2016',
#   '82.000',
#   'Yarı Otomatik',
#   'Dizel',
#   'Hatchback/5',
#   '1422 cc',
#   '90 hp',
#   'Önden Çekiş',
#   '3,5 lt',
#   '45 lt',
#   'Belirtilmemiş',
#   'Takasa Uygun',
#   'Galeriden',
#   'Favori'],
#  ['605.000',
#   'İSTANBUL / BAĞCILAR / GÖZTEPE MAHALLESİ',
#   '22354643',
#   '08 Mayıs 2023',
#   'Ford',
#   'Transit Custom',
#   '310 S Trend',
#   '2016',
#   '184.200',
#   'Düz',
#   'Dizel',
#   'Camlı Van',
#   '2198 cm3',
#   '125 hp',
#   '4x2 (Önden Çekişli)',
#   '5+1',
#   'Kamyonet',
#   '2 değişen, 3 boyalı',
#   'Takasa Uygun',
#   'Galeriden',
#   'Favori'],
#  ['1.290.000',
#   'ANKARA / AKYURT / SARACALAR MAHALLESİ',
#   '21992926',
#   '08 Mayıs 2023',
#   'Ford',
#   'Mondeo',
#   '1.5 Titanium',
#   '2020',
#   '108.000',
#   'Otomatik',
#   'Benzin',
#   'Station wagon',
#   '1498 cc',
#   '165 hp',
#   'Önden Çekiş',
#   '6,5 lt',
#   '62 lt',
#   'Belirtilmemiş',
#   'Takasa Uygun',
#   'Galeriden',
#   'Favori'],
#  ['2.350.000',
#   'İSTANBUL / BAĞCILAR / GÖZTEPE MAHALLESİ',
#   '22220831',
#   '08 Mayıs 2023',
#   'Volvo',
#   'S90',
#   '2.0 D5 Inscription',
#   '2016',
#   '158.000',
#   'Otomatik',
#   'Dizel',
#   'Sedan',
#   '1969 cc',
#   '235 hp',
#   '4WD (Sürekli)',
#   '4,8 lt',
#   '60 lt',
#   '2 değişen, 2 boyalı',
#   'Takasa Uygun Değil',
#   'Galeriden',
#   'Favori'],
#  ['1.300.000',
#   'İSTANBUL / KAĞITHANE / MERKEZ MAHALLESİ',
#   '22081459',
#   '08 Mayıs 2023',
#   'Jeep',
#   'Compass',
#   '1.3 GSE Longitude',
#   '2021',
#   '10.000',
#   'Otomatik',
#   'Benzin',
#   'Crossover',
#   '1332 cc',
#   '150 hp',
#   'Önden Çekiş',
#   '5,6 lt',
#   '55 lt',
#   'Tamamı orjinal',
#   'Takasa Uygun Değil',
#   'Galeriden',
#   'Favori'],
#  ['905.000',
#   'İSTANBUL / BAYRAMPAŞA / ORTAMAHALLE MAHALLESİ',
#   '22581130',
#   '08 Mayıs 2023',
#   'Audi',
#   'A3',
#   'A3 Sportback 1.0 TFSI Dynamic',
#   '2017',
#   '208.000',
#   'Yarı Otomatik',
#   'Benzin',
#   'Hatchback/5',
#   '999 cc',
#   '116 hp',
#   'Önden Çekiş',
#   '4,5 lt',
#   '50 lt',
#   '1 değişen, 2 boyalı',
#   '-',
#   'Galeriden',
#   'Favori'],
#  ['320.000',
#   'ANKARA / SİNCAN / AKŞEMSETTİN MAHALLESİ',
#   '22314304',
#   '08 Mayıs 2023',
#   'Fiat',
#   'Fiorino',
#   'Fiorino Combi 1.3 Multijet Pop',
#   '2017',
#   '187.000',
#   'Düz',
#   'Dizel',
#   'Camlı Van',
#   '1248 cm3',
#   '75 hp',
#   '4x2 (Önden Çekişli)',
#   '4+1',
#   'Kamyonet',
#   '1 değişen, 1 boyalı',
#   'Takasa Uygun',
#   'Galeriden',
#   'Favori'],
#  ['280.000',
#   'İSTANBUL / AVCILAR / MERKEZ MAHALLESİ',
#   '21708677',
#   '08 Mayıs 2023',
#   'Fiat',
#   'Fiorino',
#   'Fiorino Combi 1.3 Multijet Dynamic',
#   '2011',
#   '275.000',
#   'Düz',
#   'Dizel',
#   'Yarım Camlı Van',
#   '1248 cm3',
#   '75 hp',
#   '-',
#   '4+1',
#   'Kamyonet',
#   'Belirtilmemiş',
#   'Takasa Uygun',
#   'Galeriden',
#   'Favori'],
#  ['568.000',
#   'ANKARA / AKYURT / SARACALAR MAHALLESİ',
#   '22581137',
#   '08 Mayıs 2023',
#   'Chevrolet',
#   'Captiva',
#   '2.0 D LT High',
#   '2011',
#   '255.000',
#   'Otomatik',
#   'Dizel',
#   'Crossover',
#   '1991 cc',
#   '150 hp',
#   '4WD (Sürekli)',
#   '8,7 lt',
#   '65 lt',
#   '2 boyalı',
#   'Takasa Uygun',
#   'Galeriden',
#   'Favori'],
#  ['430.000',
#   'NİĞDE / MERKEZ / İLHANLI MAHALLESİ',
#   '22562721',
#   '08 Mayıs 2023',
#   'Audi',
#   'A4',
#   'A4 Sedan 1.6',
#   '2004',
#   '200.000',
#   'Düz',
#   'LPG & Benzin',
#   'Sedan',
#   '1595 cc',
#   '102 hp',
#   'Önden Çekiş',
#   '8 lt',
#   '70 lt',
#   'Belirtilmemiş',
#   'Takasa Uygun',
#   'Galeriden',
#   'Favori'],
#  ['187.000',
#   'AFYONKARAHİSAR / MERKEZ / FATİH MAHALLESİ',
#   '22543058',
#   '08 Mayıs 2023',
#   'Peugeot',
#   '206',
#   '1.4 HDi X-line',
#   '2003',
#   '197.000',
#   'Düz',
#   'Dizel',
#   'Hatchback/5',
#   '1398 cc',
#   '69 hp',
#   'Önden Çekiş',
#   '4,3 lt',
#   '50 lt',
#   'Belirtilmemiş',
#   'Takasa Uygun',
#   'Galeriden',
#   'Favori'],
#  ['120.000',
#   'AFYONKARAHİSAR / MERKEZ / FATİH MAHALLESİ',
#   '22375061',
#   '08 Mayıs 2023',
#   'Fiat',
#   'Uno',
#   '70 S',
#   '1999',
#   '300.000',
#   'Düz',
#   'LPG & Benzin',
#   'Hatchback/5',
#   '1372 cc',
#   '71 hp',
#   'Önden Çekiş',
#   '42 lt',
#   'Belirtilmemiş',
#   'Takasa Uygun',
#   'Galeriden',
#   'Favori']]

# %%
new_data[0]
# Out:
# ['1.459.500',
#  'MANİSA / ALAŞEHİR / TOYGAR MAHALLESİ',
#  '22581815',
#  '08 Mayıs 2023',
#  'Jeep',
#  'Grand Cherokee',
#  '3.0 CRD Summit',
#  '2013',
#  '277.000',
#  'Otomatik',
#  'Dizel',
#  'Crossover',
#  '2987 cc',
#  '250 hp',
#  '4WD (Sürekli)',
#  '7,5 lt',
#  '93 lt',
#  '2 değişen, 3 boyalı',
#  'Takasa Uygun Değil',
#  'Sahibinden',
#  'Favori']

# %%
type(new_data)
# Out:
# list

# %%
from pymongo import MongoClient
from dotenv import load_dotenv, find_dotenv
import os
import pprint
load_dotenv(find_dotenv())

#MongoDB için gerekli kütüphaneler
# Out:
# True

# %%
password = os.environ.get("MONGODB_PWD")
connection_string = f"mongodb+srv://emirhanbal:{password}@graduation.r68pz0b.mongodb.net/?retryWrites=true&w=majority"
client = MongoClient(connection_string)

#MONGODB ile kodumu ilişkilendirme adımı. burada database'imi bağlıyorum.

# %%
import pymongo

db = client["mydatabase"]
collection = db["mycollection"]

for item in new_data:
    data = {
        "Fiyat":item[0],
        "Adres": item[1],
        "ilan Numarası": item[2],
        "ilan Tarihi" : item[3],
        "Marka" : item[4],
        "Seri" : item[5],
        "Model" : item[6],
        "Yıl" : item[7],
        "Kilometre" : item[8],
        "Vites Tipi" : item[9],
        "Yakıt Tipi": item[10],
        "Kasa Tipi" : item[11],
        "Motor Hacmi" : item[12],
        "Motor Gücü" : item[13],
        "Çekiş" : item[14],
        "Ort. Yakıt Tüketimi" : item[15],
        "Yakıt Deposu" : item[16],
        "Boya-değişen" : item[17],
        "Takasa Uygun" : item[18]
        #"Kimden" : item[19]
        
    }
    collection.insert_one(data)
    
#local variable ve dictionary. burada data tiplerimi ve karşılığında ne olmasını istediğimi belirtiyorum.

# %%
dbs = client.list_database_names()
print(dbs)
# Out:
# ['mydatabase', 'test', 'admin', 'local']

# %%
collection.find_one()
# Out:
# {'_id': ObjectId('6459196975cd4feaff0b2025'),
#  'Fiyat': '1.459.500',
#  'Adres': 'MANİSA / ALAŞEHİR / TOYGAR MAHALLESİ',
#  'ilan Numarası': '22581815',
#  'ilan Tarihi': '08 Mayıs 2023',
#  'Marka': 'Jeep',
#  'Seri': 'Grand Cherokee',
#  'Model': '3.0 CRD Summit',
#  'Yıl': '2013',
#  'Kilometre': '277.000',
#  'Vites Tipi': 'Otomatik',
#  'Yakıt Tipi': 'Dizel',
#  'Kasa Tipi': 'Crossover',
#  'Motor Hacmi': '2987 cc',
#  'Motor Gücü': '250 hp',
#  'Çekiş': '4WD (Sürekli)',
#  'Ort. Yakıt Tüketimi': '7,5 lt',
#  'Yakıt Deposu': '93 lt',
#  'Boya-değişen': '2 değişen, 3 boyalı',
#  'Takasa Uygun': 'Takasa Uygun Değil'}

# %%
denemeSorgusu = {"Marka" : "Fiat"}
#Marka fiyat filtreleyebilmek için deneme sorgusu

# %%
Marka = input()
Seri = input()
#kullanıcıdan input almak için örnek adım
# Out:
# BMW
# 3 Serisi

# %%
denemeSorgusu = {"Marka" : Marka, "Seri" : Seri}
#sorguyu yazdırdım

# %%
for i in collection.find(denemeSorgusu, {"_id":0}):
    print(i)
#kullanıcının inputlarına göre datasetimi sorguladım ve sonuçları doğru ve eksiksiz bir biçimde verdi.
# Out:
# {'Fiyat': '1.580.000', 'Adres': 'ISPARTA / MERKEZ / GÜLİSTAN MAHALLESİ', 'ilan Numarası': '21588401', 'ilan Tarihi': '08 Mayıs 2023', 'Marka': 'BMW', 'Seri': '3 Serisi', 'Model': '320i ED 40th Year Edition', 'Yıl': '2016', 'Kilometre': '126.000', 'Vites Tipi': 'Otomatik', 'Yakıt Tipi': 'Benzin', 'Kasa Tipi': 'Sedan', 'Motor Hacmi': '1598 cc', 'Motor Gücü': '170 hp', 'Çekiş': 'Arkadan İtiş', 'Ort. Yakıt Tüketimi': '5,3 lt', 'Yakıt Deposu': '60 lt', 'Boya-değişen': 'Belirtilmemiş', 'Takasa Uygun': 'Takasa Uygun'}
# {'Fiyat': '539.500', 'Adres': 'ANKARA / YENİMAHALLE / ERGAZİ MAHALLESİ', 'ilan Numarası': '22581837', 'ilan Tarihi': '08 Mayıs 2023', 'Marka': 'BMW', 'Seri': '3 Serisi', 'Model': '320d Premium', 'Yıl': '2006', 'Kilometre': '335.000', 'Vites Tipi': 'Otomatik', 'Yakıt Tipi': 'Dizel', 'Kasa Tipi': 'Sedan', 'Motor Hacmi': '1995 cc', 'Motor Gücü': '163 hp', 'Çekiş': 'Arkadan İtiş', 'Ort. Yakıt Tüketimi': '6,7 lt', 'Yakıt Deposu': '60 lt', 'Boya-değişen': 'Belirtilmemiş', 'Takasa Uygun': 'Takasa Uygun Değil'}
# {'Fiyat': '400.000', 'Adres': 'ANKARA / ALTINDAĞ / BEŞİKKAYA MAHALLESİ', 'ilan Numarası': '22302909', 'ilan Tarihi': '08 Mayıs 2023', 'Marka': 'BMW', 'Seri': '3 Serisi', 'Model': '320i', 'Yıl': '2000', 'Kilometre': '320.000', 'Vites Tipi': 'Otomatik', 'Yakıt Tipi': 'LPG & Benzin', 'Kasa Tipi': 'Sedan', 'Motor Hacmi': '1991 cc', 'Motor Gücü': '170 hp', 'Çekiş': 'Arkadan İtiş', 'Ort. Yakıt Tüketimi': '9,4 lt', 'Yakıt Deposu': '63 lt', 'Boya-değişen': '1 değişen, 10 boyalı', 'Takasa Uygun': 'Takasa Uygun'}

# %%
for document in collection.find():
    if "Fiyat" in document:
        try:
            fiyat = int(document["Fiyat"])
            document["Fiyat"] = fiyat
            # Güncellenmiş belgeyi veritabanına geri kaydedin
            collection.replace_one({"_id": document["_id"]}, document)
        except ValueError:
            pass
        
#bu satır çalışmıyor. burada fiyat datasının tipini integer yapmaya çalıştım ancak olmadı. MongoDB içerisindeki updatelemelerle düzenlemeye çalışacağım.
